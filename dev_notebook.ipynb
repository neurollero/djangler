# %% [markdown]
# # Dev notebook for DJANGLER

# %% [markdown]
# # Get top songs from spotify

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
from typing import List, Dict, Set
import json

# %%
# Popular playlist IDs (from Spotify)
DEFAULT_PLAYLISTS = [
    "37i9dQZF1DXcBWIGoYBM5M",  # Today's Top Hits
    "37i9dQZF1DX0XUsuxWHRQd",  # RapCaviar
    "37i9dQZF1DWXRqgc9PhiG5",  # Rock Classics
    "37i9dQZF1DX4dyzvuaRJ0n",  # mint (indie/alternative)
    "37i9dQZF1DX1lVhptIYRda",  # Hot Country
    "37i9dQZF1DX4SBhb3fqCJd",  # Are & Be (R&B)
    "37i9dQZF1DX0kbJZpiYdZl",  # Hot Hits USA
    "37i9dQZF1DX4UtSsGT1Sbe",  # All Out 80s
    "37i9dQZF1DX4o1oenSJRJd",  # All Out 90s
    "37i9dQZF1DX3rxVfibe1L0",  # Mood Booster
]

SPOTIFY_CLIENT_ID = "dc02e1a590e344558af75713c5f95e02"
SPOTIFY_CLIENT_SECRET = "921349166f544ae88d4f599b4f72b5dc"

# %%
NUMBER_OF_SONGS = 10000


def setup_spotify(client_id=SPOTIFY_CLIENT_ID, client_secret=SPOTIFY_CLIENT_SECRET) -> spotipy.Spotify:
    """
    Initialize Spotify client
    
    Args:
        client_id: Spotify API client ID
        client_secret: Spotify API client secret
    
    Returns:
        Spotify client instance
    """
    auth_manager = SpotifyClientCredentials(
        client_id=client_id,
        client_secret=client_secret
    )
    return spotipy.Spotify(auth_manager=auth_manager)


def get_playlist_tracks(sp: spotipy.Spotify, playlist_id: str) -> List[Dict]:
    """
    Get all tracks from a Spotify playlist
    
    Args:
        sp: Spotify client
        playlist_id: Spotify playlist ID
    
    Returns:
        List of track dicts with title, artist, spotify_id
    """
    tracks = []
    results = sp.playlist_tracks(playlist_id)
    
    while results:
        for item in results['items']:
            if item['track'] and item['track']['name']:
                track = item['track']
                tracks.append({
                    'title': track['name'],
                    'artist': track['artists'][0]['name'],
                    'spotify_id': track['id'],
                    'album': track['album']['name'],
                    'release_date': track['album'].get('release_date', ''),
                    'popularity': track.get('popularity', 0)
                })
        
        # Pagination
        results = sp.next(results) if results['next'] else None
    
    return tracks

def get_songs_from_playlists(client_id: str,
                             client_secret: str,
                             playlist_ids: List[str] = DEFAULT_PLAYLISTS,
                             target_count: int = NUMBER_OF_SONGS) -> List[Dict]:
    """
    Fetch songs from multiple playlists until target count reached
    
    Args:
        client_id: Spotify API client ID
        client_secret: Spotify API client secret
        playlist_ids: List of Spotify playlist IDs
        target_count: Target number of unique songs
    
    Returns:
        List of unique song dicts
    """
    sp = setup_spotify(client_id, client_secret)
    
    all_tracks = []
    seen_ids = set()
    
    for playlist_id in playlist_ids:
        print(f"Fetching playlist: {playlist_id}")
        
        try:
            playlist_info = sp.playlist(playlist_id)
            print(f"  - {playlist_info['name']} ({playlist_info['tracks']['total']} tracks)")
            
            tracks = get_playlist_tracks(sp, playlist_id)
            
            # Dedupe
            for track in tracks:
                if track['spotify_id'] not in seen_ids:
                    seen_ids.add(track['spotify_id'])
                    all_tracks.append(track)
            
            print(f"  - Total unique songs: {len(all_tracks)}")
            
            if len(all_tracks) >= target_count:
                break
                
        except Exception as e:
            print(f"  - Error: {e}")
            continue
    
    return all_tracks[:target_count]


def save_song_list(tracks: List[Dict], output_path: str = "song_list.json"):
    """
    Save song list to JSON
    
    Args:
        tracks: List of track dicts
        output_path: Output file path
    """
    with open(output_path, 'w', encoding='utf-8') as f:
        json.dump(tracks, f, indent=2, ensure_ascii=False)
    
    print(f"\n✓ Saved {len(tracks)} songs to {output_path}")


def load_song_list(input_path: str = "song_list.json") -> List[Dict]:
    """
    Load song list from JSON
    
    Args:
        input_path: Input file path
    
    Returns:
        List of track dicts
    """
    with open(input_path, 'r', encoding='utf-8') as f:
        tracks = json.load(f)
    
    return tracks

# %%
# analyze_collection.py
from collections import Counter
import json

def search_playlists(sp: spotipy.Spotify, query: str, limit: int = 5) -> List[str]:
    """Search for playlists and return their IDs"""
    results = sp.search(q=query, type='playlist', limit=limit)
    # return [p['id'] for p in results['playlists']['items']]
    return [p['id'] for p in results['playlists']['items'] if p is not None]

# Get artist genres from Spotify
def get_artist_genres(sp, artist_name):
    results = sp.search(q=f"artist:{artist_name}", type='artist', limit=1)
    if results['artists']['items']:
        return results['artists']['items'][0]['genres']
    return []


def analyze_coverage(songs_file="song_list.json"):
    with open(songs_file) as f:
        songs = json.load(f)
    
    print(f"Total songs: {len(songs)}\n")
    
    # Top artists
    artists = Counter(s['artist'] for s in songs)
    print("Top 20 artists:")
    for artist, count in artists.most_common(20):
        print(f"  {artist}: {count}")
    
    # Year/decade distribution
    years = [s.get('release_date', '')[:4] for s in songs if s.get('release_date')]
    year_dist = Counter(years)
    print(f"\nDecade distribution:")
    for decade in ['1960', '1970', '1980', '1990', '2000', '2010', '2020']:
        count = sum(c for y, c in year_dist.items() if y.startswith(decade[:3]))
        print(f"  {decade}s: {count}")
    
    # Energy/valence if available
    if songs[0].get('energy'):
        avg_energy = sum(s.get('energy', 0) for s in songs) / len(songs)
        avg_valence = sum(s.get('valence', 0) for s in songs) / len(songs)
        print(f"\nAvg energy: {avg_energy:.2f}, valence: {avg_valence:.2f}")

# %%
# Example
sp = setup_spotify(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET)

# %%
# queries = ["folk rock",
#     "indie rock", 
#     "bedroom pop",
#     "alt-folk",
#     "dream pop",
#     "soul classics",
#     "soul",
#     "r&b",
#     "songwriter",
#     "acoustic",
#     "shoegaze",
#     "alternative r&b",
#     "top hits 2024", 
#     "rock classics", 
#     "hip hop hits", 
#     "country top", 
#     "indie favorites", 
#     "90s hits"
#           ]

queries = ["folk rock",
           "alt country",
           "josh ritter"
          ]

# %%
playlist_ids = []
for q in queries:
    playlist_ids.extend(search_playlists(sp, q, limit=3))

# %%
for q in queries:
    ids = search_playlists(sp, q, limit=5)
    print(f"{q}: {len(ids)} playlists")

# %%
# Then use these IDs
songs = get_songs_from_playlists(SPOTIFY_CLIENT_ID, SPOTIFY_CLIENT_SECRET, playlist_ids=playlist_ids, target_count=10000)

# %%
songs

# %%
len(songs)

# %%
save_song_list(songs, output_path="songs_list_ritter.json")

# %% [markdown]
# ## Analyze distribution of fetched songs

# %%
with open('songs_list_4000.json') as f:
    songs = json.load(f)


# Analyze current collection
all_genres = []
for song in songs:
    genres = get_artist_genres(sp, song['artist'])
    all_genres.extend(genres)

genre_counts = Counter(all_genres)
print("Top genres:", genre_counts.most_common(20))
print("\nUnderrepresented:", [g for g, c in genre_counts.items() if c < 10])

# %%
import json

# Load Spotify data
with open('songs_list_4000.json') as f:
    songs = json.load(f)

# Check first song's fields
print("Available fields:")
print(songs[0].keys())
print("\nSample song:")
for key, value in songs[0].items():
    print(f"{key}: {value}")

# Check if audio features present
has_audio = any(s.get('energy') is not None for s in songs)
print(f"\nHas audio features: {has_audio}")

# %% [markdown]
# # Lyric fetching & cleaning

# %%
import os
import re
import json
import time
from typing import Dict, List, Optional
import requests
from bs4 import BeautifulSoup

# %%
# Test songs
test_songs = [
    ("Blinding Lights", "The Weeknd"),
    ("Bohemian Rhapsody", "Queen"),
    ("Old Town Road", "Lil Nas X"),
    ("Respect", "Aretha Franklin"),
    ("Smells Like Teen Spirit", "Nirvana"),
    ("God's Plan", "Drake"),
    ("Rolling in the Deep", "Adele"),
    ("Sweet Child O' Mine", "Guns N' Roses"),
    ("Levitating", "Dua Lipa"),
    ("Lose Yourself", "Eminem")
]

GENIUS_ACCESS_TOKEN = "-XneXPQ8TZn0D1Z6cGM_PtgeyN_WowjM65Raw2Ph0Hemn0G8a-HKSjP9CzCdW4fg"

# %%
def fetch_lyrics(song_title: str, artist: str, access_token: str) -> Optional[Dict]:
    """
    Fetch raw lyrics from Genius API
    
    Args:
        song_title: Title of the song
        artist: Artist name
        access_token: Genius API access token
    
    Returns:
        Dict with 'lyrics' (raw text) and 'metadata' (title, artist, url, etc.)
        None if song not found
    """
    base_url = "https://api.genius.com"
    headers = {"Authorization": f"Bearer {access_token}"}
    
    # Search for song
    search_url = f"{base_url}/search"
    params = {"q": f"{song_title} {artist}"}
    
    try:
        response = requests.get(search_url, headers=headers, params=params)
        response.raise_for_status()
        search_data = response.json()
        
        if not search_data['response']['hits']:
            print(f"No results found for '{song_title}' by {artist}")
            return None
        
        # Get first result
        song_info = search_data['response']['hits'][0]['result']
        song_url = song_info['url']
        
        # Scrape lyrics from song page
        page = requests.get(song_url)
        html = BeautifulSoup(page.text, 'html.parser')
        
        # Genius stores lyrics in div with specific data attribute
        lyrics_divs = html.find_all('div', {'data-lyrics-container': 'true'})
        
        if not lyrics_divs:
            print(f"Could not extract lyrics for '{song_title}'")
            return None
        
        # Combine all lyric divs and preserve line breaks
        raw_lyrics = '\n'.join([div.get_text(separator='\n') for div in lyrics_divs])
        
        metadata = {
            'title': song_info['title'],
            'artist': song_info['primary_artist']['name'],
            'url': song_url,
            'release_date': song_info.get('release_date_for_display'),
            'genius_id': song_info['id']
        }
        
        return {
            'lyrics': raw_lyrics,
            'metadata': metadata
        }
        
    except Exception as e:
        print(f"Error fetching lyrics for '{song_title}': {str(e)}")
        return None

def parse_sections(raw_lyrics: str) -> List[Dict]:
    """
    Split lyrics into sections (verse, chorus, bridge, etc.)
    
    Args:
        raw_lyrics: Raw lyrics text with section headers like [Verse 1], [Chorus]
    
    Returns:
        List of dicts: [{'section_type': 'verse', 'section_number': 1, 'text': '...'}]
    """
    sections = []
    
    # Split by section headers (e.g., [Verse 1], [Chorus], [Bridge])
    # Pattern matches [Text] or [Text Number]
    section_pattern = r'\[([^\]]+)\]'
    parts = re.split(section_pattern, raw_lyrics)
    
    # parts will be: ['', 'Intro', 'lyrics...', 'Verse 1', 'lyrics...', 'Chorus', 'lyrics...']
    current_section = None
    
    for i, part in enumerate(parts):
        part = part.strip()
        if not part:
            continue
            
        # Check if this is a section header
        if i % 2 == 1:  # Odd indices are section headers (due to split behavior)
            current_section = part
        else:  # Even indices are lyrics
            if current_section and part:
                # Parse section type and number
                section_match = re.match(r'(.+?)\s*(\d+)?', current_section)
                if section_match:
                    section_type = section_match.group(1).lower().strip()
                    section_number = int(section_match.group(2)) if section_match.group(2) else None
                    
                    sections.append({
                        'section_type': section_type,
                        'section_number': section_number,
                        'text': part
                    })
    
    # If no sections found, treat entire lyrics as one section
    if not sections and raw_lyrics.strip():
        sections.append({
            'section_type': 'full',
            'section_number': None,
            'text': raw_lyrics.strip()
        })
    
    return sections

def clean_lyrics(text: str) -> str:
    """
    Clean lyrics text: remove annotations, extra whitespace, normalize
    
    Args:
        text: Raw lyrics text
    
    Returns:
        Cleaned lyrics text
    """
    # Remove text in parentheses (often production notes)
    text = re.sub(r'\([^)]*\)', '', text)
    
    # Remove extra whitespace
    text = re.sub(r'\s+', ' ', text)
    
    # Remove leading/trailing whitespace
    text = text.strip()
    
    # Normalize quotes
    text = text.replace('"', '"').replace('"', '"')
    text = text.replace(''', "'").replace(''', "'")
    
    return text

def load_songs_as_tuples(json_path: str = "song_list.json") -> List[tuple]:
    """Load song list and convert to (title, artist) tuples"""
    with open(json_path, 'r', encoding='utf-8') as f:
        songs = json.load(f)
    
    return [(song['title'], song['artist']) for song in songs]

# %% [markdown]
# ## testing each function

# %% [markdown]
# ### Fetch Lyrics

# %%
test_songs

# %%
SAVED_SONGS_FN = "songs_list_2000.json"
loaded_songs = load_songs_as_tuples(json_path=SAVED_SONGS_FN)

# %%
song_idx = 0
lyrics = fetch_lyrics(test_songs[song_idx][0], test_songs[song_idx][1], GENIUS_ACCESS_TOKEN)

# %%
lyrics

# %% [markdown]
# ### Lyrics parsing

# %%
raw_lyrics = lyrics['lyrics']
metadata = lyrics['metadata']

# %%
raw_lyrics

# %%
metadata

# %%
sections = parse_sections(raw_lyrics)

# %%
for section in sections:
    section['text'] = clean_lyrics(section['text'])

# %% [markdown]
# # Chroma embeddings

# %%
import json
import chromadb
from chromadb.utils import embedding_functions
from typing import List, Dict

# %%
def setup_chroma(db_path: str = "./lyrics_db") -> chromadb.PersistentClient:
    """
    Initialize Chroma persistent client
    
    Args:
        db_path: Path to store Chroma database
    
    Returns:
        Chroma client instance
    """
    client = chromadb.PersistentClient(path=db_path)
    print(f"Initialized Chroma database at {db_path}")
    return client


def create_collections(client: chromadb.PersistentClient, 
                      model_name: str = "all-MiniLM-L6-v2") -> tuple:
    """
    Create or get two collections: full songs and sections
    
    Args:
        client: Chroma client
        model_name: Sentence transformer model name
    
    Returns:
        Tuple of (songs_collection, sections_collection)
    """
    # Embedding function
    embedding_fn = embedding_functions.SentenceTransformerEmbeddingFunction(
        model_name=model_name
    )
    
    # Create/get collections
    songs_collection = client.get_or_create_collection(
        name="songs",
        embedding_function=embedding_fn,
        metadata={"description": "Full song lyrics embeddings"}
    )
    
    sections_collection = client.get_or_create_collection(
        name="sections",
        embedding_function=embedding_fn,
        metadata={"description": "Song section embeddings (verse, chorus, etc.)"}
    )
    
    print(f"Collections ready: songs ({songs_collection.count()} docs), sections ({sections_collection.count()} docs)")
    
    return songs_collection, sections_collection

def embed_song(song_data: Dict, songs_collection, sections_collection):
    """
    Embed and store a single song in both collections
    
    Args:
        song_data: Song dict from genius_scraper output
        songs_collection: Chroma collection for full songs
        sections_collection: Chroma collection for sections
    """
    try:
        metadata = song_data['metadata']
        song_id = str(metadata['genius_id'])
        
        # Clean metadata - ensure no None values
        clean_meta = {
            'title': str(metadata.get('title') or 'Unknown'),
            'artist': str(metadata.get('artist') or 'Unknown'),
            'url': str(metadata.get('url') or ''),
            'release_date': str(metadata.get('release_date') or 'Unknown')
        }
        
        # 1. Store full song
        songs_collection.add(
            documents=[song_data['full_lyrics']],
            metadatas=[clean_meta],
            ids=[song_id]
        )
        
        # 2. Store sections
        section_docs = []
        section_metas = []
        section_ids = []
        
        for i, section in enumerate(song_data['sections']):
            section_id = f"{song_id}_section_{i}"
            
            section_docs.append(section['text'])
            section_metas.append({
                'song_id': song_id,
                'title': str(metadata.get('title') or 'Unknown'),
                'artist': str(metadata.get('artist') or 'Unknown'),
                'section_type': str(section.get('section_type') or 'unknown'),
                'section_number': int(section.get('section_number') or 0)
            })
            section_ids.append(section_id)
        
        if section_docs:
            sections_collection.add(
                documents=section_docs,
                metadatas=section_metas,
                ids=section_ids
            )
        
        print(f"✓ Embedded: '{clean_meta['title']}' by {clean_meta['artist']} ({len(section_docs)} sections)")
        
    except Exception as e:
        title = song_data.get('metadata', {}).get('title', 'Unknown')
        print(f"⚠️  Skipping '{title}': {str(e)}")
        print(f"    Metadata: {song_data.get('metadata', {})}")


def reset_collections(db_path: str = "./lyrics_db"):
    """
    Delete and recreate collections (useful for testing)
    
    Args:
        db_path: Path to Chroma database
    """
    client = chromadb.PersistentClient(path=db_path)
    
    try:
        client.delete_collection("songs")
        client.delete_collection("sections")
        print("✓ Collections deleted")
    except:
        print("Collections already empty")


def load_and_embed_all(json_path: str = "songs_data.json", 
                       db_path: str = "./lyrics_db",
                       model_name: str = "all-MiniLM-L6-v2"):
    """
    Complete pipeline: load JSON and embed all songs
    
    Args:
        json_path: Path to songs JSON file
        db_path: Path to Chroma database
        model_name: Sentence transformer model
    """
    # Load songs
    with open(json_path, 'r', encoding='utf-8') as f:
        songs = json.load(f)
    
    print(f"Loaded {len(songs)} songs from {json_path}")
    
    # Setup Chroma
    client = setup_chroma(db_path)
    songs_collection, sections_collection = create_collections(client, model_name)
    
    # Embed each song
    for song_data in songs:
        embed_song(song_data, songs_collection, sections_collection)
    
    print(f"\n✓ Embedded all {len(songs)} songs!")
    print(f"  - Songs collection: {songs_collection.count()} documents")
    print(f"  - Sections collection: {sections_collection.count()} documents")

# %%
songs_path = "songs_data.json"
db_path = "./lyrics_db"
# model_name = "all-MiniLM-L6-v2"
model_name = "all-mpnet-base-v2"

# %%
with open(songs_path, 'r', encoding='utf-8') as f:
    songs = json.load(f)

print(len(songs))
# Out:
# 4144

# %% [markdown]
# ### Optionally clear exiting vectorDBs

# %%
reset_collections(db_path)

# %% [markdown]
# ### Continue populating vectorDBs

# %%
client = setup_chroma(db_path)
# Out:
# Initialized Chroma database at ./lyrics_db

# %%
songs_collection, sections_collection = create_collections(client, model_name)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Collections ready: songs (4091 docs), sections (25711 docs)

# %%
len(songs)
# Out:
# 4144

# %%
for song_data in songs:
        embed_song(song_data, songs_collection, sections_collection)
# Out:
# ✓ Embedded: 'Free Fallin’' by Tom Petty (9 sections)
# ✓ Embedded: 'Have You Ever Seen the Rain?' by Creedence Clearwater Revival (4 sections)
# ✓ Embedded: 'American Pie' by Don McLean (14 sections)
# ✓ Embedded: 'A Horse With No Name' by America (7 sections)
# ✓ Embedded: 'Sweet Home Alabama' by Lynyrd Skynyrd (10 sections)
# ✓ Embedded: 'For What It’s Worth' by Buffalo Springfield (8 sections)
# ✓ Embedded: 'Wild World' by Cat Stevens (7 sections)
# ✓ Embedded: 'Like a Rolling Stone' by Bob Dylan (8 sections)
# ✓ Embedded: 'Listen to the Music' by The Doobie Brothers (8 sections)
# ✓ Embedded: 'You’re So Vain' by Carly Simon (13 sections)
# ✓ Embedded: 'Sweet Caroline' by Neil Diamond (7 sections)
# ✓ Embedded: 'Maggie May' by Rod Stewart (13 sections)
# ✓ Embedded: 'Knockin’ on Heaven’s Door' by Bob Dylan (6 sections)
# ✓ Embedded: 'Me and Julio Down by the Schoolyard' by Paul Simon (6 sections)
# ✓ Embedded: 'Cecilia' by Simon & Garfunkel (5 sections)
# ✓ Embedded: 'The Boxer' by Simon & Garfunkel (8 sections)
# ✓ Embedded: 'The Times They Are A-Changin’' by Bob Dylan (5 sections)
# ✓ Embedded: 'Ooh La La' by Faces (5 sections)
# ✓ Embedded: 'Bridge Over Troubled Water' by Simon & Garfunkel (6 sections)
# ✓ Embedded: 'Hurricane' by Bob Dylan (22 sections)
# ✓ Embedded: 'Friend of the Devil' by The Grateful Dead (12 sections)
# ✓ Embedded: 'Harvest Moon' by Neil Young (7 sections)
# ✓ Embedded: 'Blowin’ in the Wind' by Bob Dylan (6 sections)
# ✓ Embedded: 'Lola' by The Kinks (9 sections)
# ✓ Embedded: 'Big Yellow Taxi' by Joni Mitchell (8 sections)
# ✓ Embedded: 'Pink Moon' by Nick Drake (4 sections)
# ✓ Embedded: 'It’s Too Late' by Carole King (8 sections)
# ✓ Embedded: 'Time in a Bottle' by Jim Croce (5 sections)
# ✓ Embedded: 'Father and Son' by Cat Stevens (4 sections)
# ✓ Embedded: 'The Gambler' by Kenny Rogers (8 sections)
# ✓ Embedded: 'Peace Train' by Cat Stevens (12 sections)
# ✓ Embedded: 'A Case of You' by Joni Mitchell (8 sections)
# ✓ Embedded: 'The Wind' by Cat Stevens (4 sections)
# ✓ Embedded: 'Don’t Think Twice, It’s All Right' by Bob Dylan (4 sections)
# ✓ Embedded: 'The Only Living Boy in New York' by Simon & Garfunkel (7 sections)
# ✓ Embedded: 'Mr. Tambourine Man' by Bob Dylan (9 sections)
# ✓ Embedded: 'Angel from Montgomery' by John Prine (6 sections)
# ✓ Embedded: 'El Cóndor Pasa (If I Could)' by Simon & Garfunkel (5 sections)
# ✓ Embedded: 'California' by Joni Mitchell (9 sections)
# ✓ Embedded: 'Werewolves of London' by Warren Zevon (8 sections)
# ✓ Embedded: 'Touch of Grey' by The Grateful Dead (11 sections)
# ✓ Embedded: 'These Days' by Nico (4 sections)
# ✓ Embedded: 'River' by Joni Mitchell (7 sections)
# ✓ Embedded: 'Thirteen' by Big Star (3 sections)
# ✓ Embedded: 'Me and You and a Dog Named Boo' by Lobo (8 sections)
# ✓ Embedded: 'Venus' by Shocking Blue (6 sections)
# ✓ Embedded: 'Catch the Wind' by Donovan (5 sections)
# ✓ Embedded: 'Bye Bye Love' by ​The Everly Brothers (5 sections)
# ✓ Embedded: 'Puff, The Magic Dragon' by Peter, Paul and Mary (7 sections)
# ✓ Embedded: 'Girl from the North Country' by Bob Dylan (5 sections)
# ✓ Embedded: 'All I Want' by Joni Mitchell (3 sections)
# ✓ Embedded: 'The Old Man’s Back Again (Dedicated to the Neo-Stalinist Regime)' by Scott Walker (8 sections)
# ✓ Embedded: 'While I Play' by Bee Gees (1 sections)
# ✓ Embedded: 'A Summer Song' by Chad & Jeremy (10 sections)
# ✓ Embedded: 'Walk on the Wild Side' by Lou Reed (12 sections)
# ✓ Embedded: 'Strangers' by The Kinks (6 sections)
# ✓ Embedded: 'Pale Blue Eyes' by The Velvet Underground (10 sections)
# ✓ Embedded: 'Ventura Highway' by America (6 sections)
# ✓ Embedded: 'Never Marry a Railroad Man' by Shocking Blue (1 sections)
# ✓ Embedded: 'Take Me Home, Country Roads' by John Denver (7 sections)
# ✓ Embedded: 'Wake Up Little Susie' by ​The Everly Brothers (12 sections)
# ✓ Embedded: 'Sundown' by Gordon Lightfoot (8 sections)
# ✓ Embedded: 'Summer Breeze' by Seals and Crofts (7 sections)
# ✓ Embedded: 'Make It With You' by Bread (8 sections)
# ✓ Embedded: 'A Well Respected Man' by The Kinks (8 sections)
# ✓ Embedded: 'Diamonds and Rust' by Joan Baez (5 sections)
# ✓ Embedded: 'Ruby Tuesday' by The Rolling Stones (7 sections)
# ✓ Embedded: 'Turn! Turn! Turn! (To Everything There Is a Season)' by The Byrds (8 sections)
# ✓ Embedded: 'Thunder Road' by Bruce Springsteen (7 sections)
# ✓ Embedded: 'Operator (That’s Not the Way It Feels)' by Jim Croce (7 sections)
# ✓ Embedded: 'Dream a Little Dream of Me' by The Mamas & The Papas (8 sections)
# ✓ Embedded: 'Coward of the County' by Kenny Rogers (8 sections)
# ✓ Embedded: 'Tangled Up in Blue' by Bob Dylan (7 sections)
# ✓ Embedded: 'Amie' by Pure Prairie League (8 sections)
# ✓ Embedded: 'Up on cripple creek - 2000 - remaster' by The Band (1 sections)
# ✓ Embedded: 'Handle with Care' by Traveling Wilburys (9 sections)
# ✓ Embedded: 'Wasn’t Born to Follow' by The Byrds (6 sections)
# ✓ Embedded: 'Going Up the Country' by Canned Heat (5 sections)
# ✓ Embedded: 'California Stars' by Billy Bragg and Wilco (5 sections)
# ✓ Embedded: 'I Hope That I Don’t Fall in Love with You' by Tom Waits (5 sections)
# ✓ Embedded: 'Me and Bobby McGee' by Janis Joplin (7 sections)
# ✓ Embedded: 'Ramblin’ Man' by The Allman Brothers Band (7 sections)
# ✓ Embedded: 'Garden Party' by Ricky Nelson (5 sections)
# ✓ Embedded: 'The night they drove old dixie down - 2000 digital remaster' by The Band (1 sections)
# ✓ Embedded: 'The Universal Soldier' by Buffy Sainte-Marie (6 sections)
# ✓ Embedded: 'You Ain’t Goin’ Nowhere' by The Byrds (1 sections)
# ✓ Embedded: 'The Last Thing on My Mind' by Tom Paxton (6 sections)
# ✓ Embedded: 'Masters of War' by Bob Dylan (8 sections)
# ✓ Embedded: 'Blues Run the Game (2001 - Remaster)' by Jackson C. Frank (7 sections)
# ✓ Embedded: 'Eve of Destruction' by Barry McGuire (9 sections)
# ✓ Embedded: 'Long as I Can See the Light' by Creedence Clearwater Revival (5 sections)
# ✓ Embedded: 'You Can’t Always Get What You Want' by The Rolling Stones (10 sections)
# ✓ Embedded: 'Loves Me Like a Rock' by Paul Simon (2 sections)
# ✓ Embedded: '505' by Arctic Monkeys (5 sections)
# ✓ Embedded: 'Still Beating' by Mac DeMarco (4 sections)
# ✓ Embedded: 'Telescope' by Cage The Elephant (8 sections)
# ✓ Embedded: 'Habit' by Still Woozy (4 sections)
# ✓ Embedded: 'Tungs' by The Frights (8 sections)
# ✓ Embedded: 'Pleaser' by Wallows (8 sections)
# ✓ Embedded: 'Brazil' by Declan McKenna (7 sections)
# ✓ Embedded: 'Dope On A Rope' by The Growlers (8 sections)
# ✓ Embedded: 'Arabella' by Arctic Monkeys (8 sections)
# ✓ Embedded: 'Electric Love' by BØRNS (8 sections)
# ✓ Embedded: 'Fluorescent Adolescent' by Arctic Monkeys (7 sections)
# ✓ Embedded: 'Babydoll' by Dominic Fike (3 sections)
# ✓ Embedded: 'Cigarette Daydreams' by Cage The Elephant (8 sections)
# ✓ Embedded: 'Window' by Still Woozy (10 sections)
# ✓ Embedded: 'Why’d You Only Call Me When You’re High?' by Arctic Monkeys (6 sections)
# ✓ Embedded: 'Pool House' by The Backseat Lovers (6 sections)
# ✓ Embedded: 'Cooks' by Still Woozy (6 sections)
# ✓ Embedded: 'Can I Call You Tonight?' by Dayglow (7 sections)
# ✓ Embedded: '​way ​​it ​goes' by Hippo Campus (7 sections)
# ✓ Embedded: 'Search Party!' by The All-American Rejects (6 sections)
# ✓ Embedded: 'My Kind of Woman' by Mac DeMarco (4 sections)
# ✓ Embedded: 'Eggshell Tap Dancer' by The All-American Rejects (9 sections)
# ✓ Embedded: 'Take Me Out' by Franz Ferdinand (6 sections)
# ✓ Embedded: 'Put Your Records On' by Ritt Momney (10 sections)
# ✓ Embedded: 'Burn It Down' by Lansdowne (8 sections)
# ✓ Embedded: 'You Know It' by Colony House (6 sections)
# ✓ Embedded: 'Guessing Games' by James And The Cold Gun (1 sections)
# ✓ Embedded: 'I Love You So' by The Walters (5 sections)
# ✓ Embedded: 'Feeling Lonely' by boy pablo (5 sections)
# ✓ Embedded: 'Sweet Talk' by Saint Motel (8 sections)
# ✓ Embedded: 'Under Control' by The Strokes (8 sections)
# ✓ Embedded: 'Unbothered' by Omar Apollo (3 sections)
# ✓ Embedded: 'All These Things That I’ve Done' by The Killers (9 sections)
# ✓ Embedded: 'I Wanna Be Yours' by Arctic Monkeys (7 sections)
# ✓ Embedded: 'Hot Rod' by Dayglow (6 sections)
# ✓ Embedded: 'Feels Like We Only Go Backwards' by Tame Impala (5 sections)
# ✓ Embedded: 'Back Against the Wall' by Cage The Elephant (9 sections)
# ✓ Embedded: 'Hurt Me Most' by weknewnothing (5 sections)
# ✓ Embedded: 'OK' by Wallows (7 sections)
# ✓ Embedded: 'Above the Lake' by James And The Cold Gun (1 sections)
# ✓ Embedded: 'Sit Next to Me' by Foster the People (10 sections)
# ✓ Embedded: 'Remember When' by Wallows (7 sections)
# ✓ Embedded: 'Big screen' by Rohan Kapur (1 sections)
# ✓ Embedded: 'Lovers Rock' by TV Girl (7 sections)
# ✓ Embedded: 'Talk Too Much' by COIN (6 sections)
# ✓ Embedded: '​buttercup' by Hippo Campus (6 sections)
# ✓ Embedded: 'R U Mine?' by Arctic Monkeys (7 sections)
# ✓ Embedded: 'Elephant' by Tame Impala (2 sections)
# ✓ Embedded: 'Steady, as She Goes' by The Raconteurs (13 sections)
# ✓ Embedded: 'End of Beginning' by Djo (6 sections)
# ✓ Embedded: 'ALL NIGHT LONG' by Mishaal Tamer (11 sections)
# ✓ Embedded: 'Clint Eastwood' by Gorillaz (7 sections)
# ✓ Embedded: 'Maple Syrup' by The Backseat Lovers (5 sections)
# ✓ Embedded: 'Bambi' by Hippo Campus (5 sections)
# ✓ Embedded: 'Space Song' by Beach House (4 sections)
# ✓ Embedded: 'Candy Wrappers' by Summer Salt (7 sections)
# ✓ Embedded: 'Televised' by HUNNY (6 sections)
# ✓ Embedded: 'Kilby Girl' by The Backseat Lovers (4 sections)
# ✓ Embedded: 'Weekend Friend' by Goth Babe (4 sections)
# ✓ Embedded: 'Some' by Steve Lacy (4 sections)
# ✓ Embedded: 'Money' by The Drums (8 sections)
# ✓ Embedded: 'Dark Red' by Steve Lacy (6 sections)
# ✓ Embedded: 'C U Girl' by Steve Lacy (4 sections)
# ✓ Embedded: 'Bigger Boys and Stolen Sweethearts' by Arctic Monkeys (9 sections)
# ✓ Embedded: 'Salad Days' by Mac DeMarco (10 sections)
# ✓ Embedded: 'Come a Little Closer' by Cage The Elephant (6 sections)
# ✓ Embedded: 'Let It Happen' by Tame Impala (7 sections)
# ✓ Embedded: 'Paint Me Silver' by Pond (9 sections)
# ✓ Embedded: 'Last Nite' by The Strokes (5 sections)
# ✓ Embedded: 'Night Ride' by The Growlers (7 sections)
# ✓ Embedded: 'What You Know' by Two Door Cinema Club (5 sections)
# ✓ Embedded: 'New Person, Same Old Mistakes' by Tame Impala (6 sections)
# ✓ Embedded: 'When You Were Made' by The Growlers (4 sections)
# ✓ Embedded: 'Sun' by Two Door Cinema Club (7 sections)
# ✓ Embedded: 'Looking Out for You' by Joy Again (4 sections)
# ✓ Embedded: 'Homage' by Mild High Club (5 sections)
# ✓ Embedded: 'Teddy Picker' by Arctic Monkeys (7 sections)
# ✓ Embedded: 'Kids' by Current Joys (6 sections)
# ✓ Embedded: '7' by Catfish and the Bottlemen (8 sections)
# ✓ Embedded: 'T-Shirt Weather' by Circa Waves (9 sections)
# ✓ Embedded: 'Corduroy Dreams' by Rex Orange County (4 sections)
# ✓ Embedded: 'Ain’t No Rest for the Wicked' by Cage The Elephant (6 sections)
# ✓ Embedded: 'Disco' by Surf Curse (4 sections)
# ✓ Embedded: 'Peace Blossom Boogy' by Babe Rainbow (6 sections)
# ✓ Embedded: 'Reservoir Dawgs' by Beach Goons (5 sections)
# ✓ Embedded: 'Daylight/Moonlight' by The Red Pears (4 sections)
# ✓ Embedded: 'Gutter Girl' by Hot Flash Heat Wave (4 sections)
# ✓ Embedded: 'Mardy Bum' by Arctic Monkeys (6 sections)
# ✓ Embedded: 'A-Punk' by Vampire Weekend (6 sections)
# ✓ Embedded: 'Someday' by The Strokes (6 sections)
# ✓ Embedded: 'Days' by The Drums (7 sections)
# ✓ Embedded: 'Sweet Emotion' by The Kooks (12 sections)
# ✓ Embedded: 'Cough Syrup' by Young the Giant (7 sections)
# ✓ Embedded: 'Live Well' by Palace (8 sections)
# ✓ Embedded: 'Take It or Leave It' by Cage The Elephant (6 sections)
# ✓ Embedded: 'Threat of Joy' by The Strokes (8 sections)
# ✓ Embedded: 'South' by Hippo Campus (5 sections)
# ✓ Embedded: 'Too Much Time Together' by San Cisco (8 sections)
# ✓ Embedded: 'City Club' by The Growlers (6 sections)
# ✓ Embedded: 'Suicide Saturday' by Hippo Campus (6 sections)
# ✓ Embedded: 'Cocoon' by Catfish and the Bottlemen (11 sections)
# ✓ Embedded: 'Taking Pictures of You' by The Kooks (5 sections)
# ✓ Embedded: 'Ryd' by Steve Lacy (3 sections)
# ✓ Embedded: 'Confidence' by Ocean Alley (8 sections)
# ✓ Embedded: 'Small Talk' by Briston Maroney (6 sections)
# ✓ Embedded: 'Bittersweet' by Greer (9 sections)
# ✓ Embedded: 'Sunflower' by Rex Orange County (7 sections)
# ✓ Embedded: 'Too Late' by The Happy Fits (9 sections)
# ✓ Embedded: 'Freakin’ Out on the Interstate' by Briston Maroney (6 sections)
# ✓ Embedded: 'Let’s Pretend' by Del Water Gap (1 sections)
# ✓ Embedded: 'Silhouettes' by Colony House (6 sections)
# ✓ Embedded: 'Lovesong (The Way)' by Charlie Burg (6 sections)
# ✓ Embedded: 'Run the World!!!' by Dayglow (6 sections)
# ✓ Embedded: 'I Think I Like When It Rains' by WILLIS (Band) (5 sections)
# ✓ Embedded: 'Sports' by Beach Bunny (7 sections)
# ✓ Embedded: 'If You Know That I’m Lonely' by FUR (6 sections)
# ✓ Embedded: 'Freaks' by Surf Curse (4 sections)
# ✓ Embedded: 'Where’d All The Time Go?' by Dr. Dog (7 sections)
# ✓ Embedded: 'Still a Friend' by The Backseat Lovers (1 sections)
# ✓ Embedded: 'Staring' by Tipling Rock (7 sections)
# ✓ Embedded: '​Everytime' by boy pablo (5 sections)
# ✓ Embedded: 'Davy Crochet' by The Backseat Lovers (3 sections)
# ✓ Embedded: 'Shampoo Bottles' by Peach Pit (5 sections)
# ✓ Embedded: 'Chasing Waves' by Vista Kicks (1 sections)
# ✓ Embedded: 'Oh, Honey Baby' by Mustard Service (4 sections)
# ✓ Embedded: 'The Bad Thing' by Arctic Monkeys (5 sections)
# ✓ Embedded: 'Chicago' by flipturn (6 sections)
# ✓ Embedded: 'Like or Like Like' by Miniature Tigers (5 sections)
# ✓ Embedded: 'Stella Brown' by Jelani Aryeh (7 sections)
# ✓ Embedded: 'Space Cadet' by The Technicolors (8 sections)
# ✓ Embedded: 'Birds Dont Sing' by TV Girl (6 sections)
# ✓ Embedded: 'Driving to Hawaii' by Summer Salt (1 sections)
# ✓ Embedded: 'Darlin’' by Houndmouth (4 sections)
# ✓ Embedded: 'Silhouette' by Ax and the Hatchetmen (9 sections)
# ✓ Embedded: 'American Spirits' by Inner Wave (4 sections)
# ✓ Embedded: 'Ghostride' by Crumb (4 sections)
# ✓ Embedded: 'Feeding the Family' by Spacey Jane (6 sections)
# ✓ Embedded: 'Congratulations' by MGMT (6 sections)
# ✓ Embedded: 'So Good at Being in Trouble' by Unknown Mortal Orchestra (6 sections)
# ✓ Embedded: 'Patience' by Tame Impala (8 sections)
# ✓ Embedded: 'In Your Arms' by Sunbeam Sound Machine (1 sections)
# ✓ Embedded: 'Ditch' by Gus Dapperton (5 sections)
# ✓ Embedded: 'Eventually' by Tame Impala (4 sections)
# ✓ Embedded: 'Skiptracing' by Mild High Club (5 sections)
# ✓ Embedded: 'The Way Things Change' by Yellow Days (7 sections)
# ✓ Embedded: 'Omaha' by Toro y Moi (7 sections)
# ✓ Embedded: 'Uptown Folks' by DOPE LEMON (6 sections)
# ✓ Embedded: 'Down the Line' by Beach Fossils (5 sections)
# ✓ Embedded: 'Disciples' by Tame Impala (4 sections)
# ✓ Embedded: 'Is This It' by The Strokes (6 sections)
# ✓ Embedded: 'Beach Bummer' by No Vacation (6 sections)
# ✓ Embedded: 'Sensitivity' by Worn-Tin (6 sections)
# ✓ Embedded: 'Eclipse' by Inner Wave (1 sections)
# ✓ Embedded: 'Lava' by Still Woozy (7 sections)
# ✓ Embedded: 'Chateau (Feel Alright)' by Djo (5 sections)
# ✓ Embedded: 'Limestone' by Magic City Hippies (6 sections)
# ✓ Embedded: 'Nothing In Return' by Monsune (1 sections)
# ✓ Embedded: 'All Your Love' by Jakob (4 sections)
# ✓ Embedded: 'Goodbye Baby' by The Walters (8 sections)
# ✓ Embedded: 'Dræm Girl' by No Vacation (3 sections)
# ✓ Embedded: 'Nothing Has Changed' by The Polar Boys (7 sections)
# ✓ Embedded: 'What’s New' by Ax and the Hatchetmen (6 sections)
# ✓ Embedded: 'Stuck in the Middle' by Tai Verdes (10 sections)
# ✓ Embedded: 'Hey Lover!' by Wabie (9 sections)
# ✓ Embedded: 'Swing Lynn' by Harmless (3 sections)
# ✓ Embedded: 'Bye Bye Baby' by Greer (9 sections)
# ✓ Embedded: 'Understand' by Greer (9 sections)
# ✓ Embedded: 'Only in the West' by Yeek (6 sections)
# ✓ Embedded: 'Young' by Vacations (4 sections)
# ✓ Embedded: 'Sea Sick' by Binki (6 sections)
# ✓ Embedded: 'June' by Briston Maroney (9 sections)
# ✓ Embedded: 'Stay Clear' by Greer (5 sections)
# ✓ Embedded: 'Elevator Days' by The Backseat Lovers (1 sections)
# ✓ Embedded: 'Goofy' by Ax and the Hatchetmen (8 sections)
# ✓ Embedded: 'Oh My God You Are Fine' by Blue Rain Boots (6 sections)
# ✓ Embedded: 'Cornerstone' by Arctic Monkeys (7 sections)
# ✓ Embedded: 'Nova Scotia 500' by Boyscott (3 sections)
# ✓ Embedded: 'Rare Hearts' by The Growlers (5 sections)
# ✓ Embedded: 'Brakelights' by Omar Apollo (1 sections)
# ✓ Embedded: 'Roddy' by Djo (7 sections)
# ✓ Embedded: 'When the Sun Goes Down' by Arctic Monkeys (6 sections)
# ✓ Embedded: 'Marceline' by Vista Kicks (5 sections)
# ✓ Embedded: 'Where Is My Mind?' by Pixies (8 sections)
# ✓ Embedded: 'New Flesh' by Current Joys (4 sections)
# ✓ Embedded: 'Your Graduation' by Modern Baseball (5 sections)
# ✓ Embedded: 'Little Dark Age' by MGMT (10 sections)
# ✓ Embedded: 'Jealous' by Eyedress (5 sections)
# ✓ Embedded: 'Selfless' by The Strokes (6 sections)
# ✓ Embedded: 'Always Where I Need To Be' by The Kooks (7 sections)
# ✓ Embedded: 'A Change Is Gonna Come' by Greta Van Fleet (7 sections)
# ✓ Embedded: 'Something About You' by Eyedress (5 sections)
# ✓ Embedded: 'Alaska' by Maggie Rogers (7 sections)
# ✓ Embedded: 'Pretty Girl' by Clairo (4 sections)
# ✓ Embedded: 'Flaming Hot Cheetos' by Clairo (7 sections)
# ✓ Embedded: 'Hello?' by Clairo (5 sections)
# ✓ Embedded: 'Lover Is a Day' by Cuco (5 sections)
# ✓ Embedded: '4EVER' by Clairo (5 sections)
# ✓ Embedded: '​dream girl' by ​crisaunt (4 sections)
# ✓ Embedded: 'Mrs Magic' by Strawberry Guy (6 sections)
# ✓ Embedded: 'Show Me How' by Men I Trust (6 sections)
# ✓ Embedded: 'Cariño' by The Marías (10 sections)
# ✓ Embedded: 'From the Subway Train' by Vansire (1 sections)
# ✓ Embedded: 'Someone To Spend Time With' by Los Retros (5 sections)
# ✓ Embedded: 'Over the Moon' by The Marías (6 sections)
# ✓ Embedded: 'You Might Be Sleeping' by Jakob (4 sections)
# ✓ Embedded: 'F Song' by Strawberry Guy (5 sections)
# ✓ Embedded: 'I Hope to Be Around' by Men I Trust (6 sections)
# ✓ Embedded: 'I Don’t Know You' by The Marías (5 sections)
# ✓ Embedded: 'Velvet Light' by Jakob (4 sections)
# ✓ Embedded: 'Lucky Love' by Michael Seyer (4 sections)
# ✓ Embedded: 'Dontmakemefallinlove' by Cuco (4 sections)
# ✓ Embedded: 'Nice Boys' by TEMPOREX (4 sections)
# ✓ Embedded: 'Drown' by Cuco (9 sections)
# ✓ Embedded: 'SLOW DANCING IN THE DARK' by Joji (6 sections)
# ✓ Embedded: 'Summer Time High Time' by Cuco (6 sections)
# ✓ Embedded: 'Cupid’s Quiver' by Cuco (1 sections)
# ✓ Embedded: 'For You' by Luna Luna (8 sections)
# ✓ Embedded: 'Mystery girl' by Housecall (7 sections)
# ✓ Embedded: 'i hope she loves me back' by boy pablo (6 sections)
# ✓ Embedded: 'Care' by TEMPOREX (3 sections)
# ✓ Embedded: 'You’ll Be on My Mind' by Jakob (4 sections)
# ✓ Embedded: '80's High School' by CASTLEBEAT (1 sections)
# ✓ Embedded: 'You and I' by Jakob (4 sections)
# ✓ Embedded: 'Cuz You’re My Girl' by Yung Heazy (7 sections)
# ✓ Embedded: 'Lo Que Siento' by Cuco (6 sections)
# ✓ Embedded: '777' by ​lilbootycall (6 sections)
# ✓ Embedded: 'Last Day on Earth' by Los Retros (5 sections)
# ✓ Embedded: 'Amor de Siempre' by Cuco (5 sections)
# ✓ Embedded: 'Cherry Love' by Katzù Oso (1 sections)
# ✓ Embedded: 'Coqueta' by Katzù Oso (1 sections)
# ✓ Embedded: 'Crazy4luvinU' by Katzù Oso (7 sections)
# ✓ Embedded: 'Pretty Girls' by Michael Seyer (8 sections)
# ✓ Embedded: 'Daydream' by TEMPOREX (1 sections)
# ✓ Embedded: 'Bubble Gum' by Clairo (4 sections)
# ✓ Embedded: 'Falling For U' by Peachy! (4 sections)
# ✓ Embedded: 'pink bubblegum' by ​lavi kou (3 sections)
# ✓ Embedded: 'What Dreams Are Made Of' by Evann McIntosh (5 sections)
# ✓ Embedded: 'Ocean~' by Jon Kuwada (5 sections)
# ✓ Embedded: 'Loving Is Easy' by Rex Orange County (7 sections)
# ✓ Embedded: 'Apricot Princess' by Rex Orange County (3 sections)
# ✓ Embedded: 'Thunder' by Roy Blair (7 sections)
# ✓ Embedded: 'Untitled' by Rex Orange County (1 sections)
# ✓ Embedded: 'A Song About Being Sad' by Rex Orange County (2 sections)
# ✓ Embedded: 'Dance, Baby!' by boy pablo (6 sections)
# ✓ Embedded: 'Beach House' by boy pablo (1 sections)
# ✓ Embedded: '​kiss u better' by Katzù Oso (5 sections)
# ✓ Embedded: '​feel u' by Okayceci (6 sections)
# ✓ Embedded: '​just friends' by potsu (2 sections)
# ✓ Embedded: 'I’m sorry i like you' by Burbank (1 sections)
# ✓ Embedded: 'Sweet Bird' by Young Hunting (1 sections)
# ✓ Embedded: 'Ain’t Gonna Call' by Yellow House (4 sections)
# ✓ Embedded: 'A Little While' by Yellow Days (8 sections)
# ✓ Embedded: 'You' by Sebastian Roca (1 sections)
# ✓ Embedded: 'Moon Lovers' by Leo Herca (1 sections)
# ✓ Embedded: 'When I’m With You' by LilTrxptendo (5 sections)
# ✓ Embedded: 'Piel Canela' by Cuco (2 sections)
# ✓ Embedded: 'Cherry Cola' by Jon Kuwada (5 sections)
# ✓ Embedded: '​hey girl' by boy pablo (6 sections)
# ✓ Embedded: 'Take Me to the Crib' by Brad Stank (1 sections)
# ✓ Embedded: 'Bad Mood' by Triathalon (5 sections)
# ✓ Embedded: 'Never Have Enough' by Los Retros (4 sections)
# ✓ Embedded: 'How Was Your Day?' by Mellow Fellow (5 sections)
# ✓ Embedded: 'Heaven' by Clairo (5 sections)
# ✓ Embedded: 'Friends' by Los Retros (3 sections)
# ✓ Embedded: 'Moon Ride' by Los Retros (5 sections)
# ✓ Embedded: 'Necromancer' by Joy Again (3 sections)
# ✓ Embedded: 'Let It Pass' by Jakob (4 sections)
# ✓ Embedded: 'Birch Tree' by Strawberry Guy (7 sections)
# ✓ Embedded: 'Numb' by Men I Trust (2 sections)
# ✓ Embedded: 'How (demo)' by Clairo (2 sections)
# ✓ Embedded: 'Tinder Song' by VICTOR INTERNET (4 sections)
# ✓ Embedded: 'Hit or Miss' by BOYO (5 sections)
# ✓ Embedded: 'Amtrak' by Los Retros (4 sections)
# ✓ Embedded: 'What Would I Do?' by Strawberry Guy (6 sections)
# ✓ Embedded: 'Ruthless' by The Marías (9 sections)
# ✓ Embedded: 'Teenage Blue' by Dreamgirl (7 sections)
# ✓ Embedded: 'Lava Lamp' by Cuco (5 sections)
# ✓ Embedded: 'Eleven Weeks' by Vansire (1 sections)
# ✓ Embedded: 'Morning Sex' by Ralph Castelli (4 sections)
# ✓ Embedded: 'Without You' by Strawberry Guy (6 sections)
# ✓ Embedded: 'I Feel Best When I’m Alone' by Michael Seyer (1 sections)
# ✓ Embedded: 'Crime' by Chek (3 sections)
# ✓ Embedded: 'Sunshine Girl - Demo' by Jakob (5 sections)
# ✓ Embedded: 'Sunshine Girl - Pt. 2' by Jakob (1 sections)
# ✓ Embedded: 'Next to Me' by Jakob (2 sections)
# ✓ Embedded: 'Commitment' by Luna Luna (7 sections)
# ✓ Embedded: 'Supplier!' by ​crisaunt (5 sections)
# ✓ Embedded: 'Sofia' by Clairo (6 sections)
# ✓ Embedded: 'Bags' by Clairo (5 sections)
# ✓ Embedded: 'Let’s Skip to the Wedding' by Eyedress (3 sections)
# ✓ Embedded: 'The Things You Do (to Me)' by Mark Whalen (5 sections)
# ✓ Embedded: 'All I Wanna Do' by Jakob (2 sections)
# ✓ Embedded: 'Intermission' by Strawberry Guy (1 sections)
# ✓ Embedded: '2031' by Inner Wave (5 sections)
# ✓ Embedded: 'Pink & Blue' by VALENTINE (1 sections)
# ✓ Embedded: 'Girl, I’ll Take U Anywhere' by Yung Heazy (5 sections)
# ✓ Embedded: 'Pastel Pink' by ​crisaunt (4 sections)
# ✓ Embedded: 'Airplane Mode' by Limbo (6 sections)
# ✓ Embedded: 'Dead Weight' by Jack Stauber (8 sections)
# ✓ Embedded: 'Steeeam' by Shelly (2 sections)
# ✓ Embedded: 'Let’s Keep it Virtual' by TEMPOREX (2 sections)
# ✓ Embedded: 'Tunnel of Love' by ilyTOMMY (4 sections)
# ✓ Embedded: 'Midnight Blues' by UMI (5 sections)
# ✓ Embedded: 'Losing You' by boy pablo (6 sections)
# ✓ Embedded: 'Call Me' by Soap (Pop) (1 sections)
# ✓ Embedded: 'Melting' by Kali Uchis (4 sections)
# ✓ Embedded: 'We Had to End It' by Cuco (1 sections)
# ✓ Embedded: 'French Girl' by Oscar Lang (7 sections)
# ✓ Embedded: 'Panama' by Sports (6 sections)
# ✓ Embedded: 'Warned You' by Good Morning (4 sections)
# ✓ Embedded: 'Only In My Dreams' by The Marías (3 sections)
# ✓ Embedded: 'Seven' by Men I Trust (5 sections)
# ✓ Embedded: 'Alone Together' by Billy Uomo (5 sections)
# ✓ Embedded: 'Daydream' by Luna Luna (7 sections)
# ✓ Embedded: 'Forevermore' by Cuco (2 sections)
# ✓ Embedded: 'Winter’s Ballad' by Cuco (1 sections)
# ✓ Embedded: 'Unlucky' by Lunar Vacation (7 sections)
# ✓ Embedded: 'One and Only' by Cuco (5 sections)
# ✓ Embedded: 'Lost / Heart' by Cuco (6 sections)
# ✓ Embedded: 'Basta Ya' by The Marías (4 sections)
# ✓ Embedded: 'Soundtrack for Your Backseat' by Sundiver ca (2 sections)
# ✓ Embedded: 'Don’t Forget' by Luna Luna (8 sections)
# ✓ Embedded: 'Perfect Sweet Blue' by Jakob (3 sections)
# ✓ Embedded: 'Best Friend' by Cuco (4 sections)
# ✓ Embedded: 'Italo Disco' by Last Dinosaurs (3 sections)
# ✓ Embedded: 'Delayed' by TEMPOREX (4 sections)
# ✓ Embedded: 'Oh Honey' by Sundiver ca (7 sections)
# ✓ Embedded: 'Every Time Around' by Vansire (5 sections)
# ✓ Embedded: 'Ring Around the Rosie' by Michael Seyer (5 sections)
# ✓ Embedded: 'Fro' by Luna Luna (1 sections)
# ✓ Embedded: 'Only You' by Luna Luna (4 sections)
# ✓ Embedded: 'Comb My Hair' by Pretty Boy Aaron (5 sections)
# ✓ Embedded: 'You Are the Right One' by Sports (4 sections)
# ✓ Embedded: 'Prune, You Talk Funny' by Gus Dapperton (7 sections)
# ✓ Embedded: 'Different State of Mind' by Kid Bloom (1 sections)
# ✓ Embedded: 'That I Miss You' by Vansire (5 sections)
# ✓ Embedded: 'April' by Jakob (1 sections)
# ✓ Embedded: 'Sweet Honey' by Los Retros (2 sections)
# ✓ Embedded: 'Relax' by Vacations (4 sections)
# ✓ Embedded: 'Flirting in Space' by Brad Stank (4 sections)
# ✓ Embedded: '2 Hold U' by Clairo (3 sections)
# ✓ Embedded: 'OUTTA MY MIND' by Monsune (9 sections)
# ✓ Embedded: 'I Can’t Dance' by Michael Seyer (6 sections)
# ✓ Embedded: 'Nostalgic Feel' by Bedroom (2 sections)
# ✓ Embedded: 'Give It Up To You' by Katzù Oso (5 sections)
# ✓ Embedded: 'Ugotme' by Omar Apollo (4 sections)
# ✓ Embedded: 'How It Starts' by Loma (1 sections)
# ✓ Embedded: 'Katie Cruel' by Ora Cogan (1 sections)
# ✓ Embedded: 'Calling on Angels' by Amelia Magdalena (4 sections)
# ✓ Embedded: 'Flatlands' by Chelsea Wolfe (4 sections)
# ✓ Embedded: 'Two Minds' by Amelia Magdalena (1 sections)
# ✓ Embedded: 'Rattle Trap' by Sophie Thatcher (4 sections)
# ✓ Embedded: 'Have Heaven' by Florist (6 sections)
# ✓ Embedded: 'Like Sweetness' by Warpaint (8 sections)
# ✓ Embedded: 'Longing' by She Keeps Bees (4 sections)
# ✓ Embedded: 'The End Where I Begin' by Amelia Magdalena (5 sections)
# ✓ Embedded: 'The Rip' by Portishead (5 sections)
# ✓ Embedded: 'Dust It Off' by The Dø (1 sections)
# ✓ Embedded: 'Sunrise' by Ormella (4 sections)
# ✓ Embedded: 'Dream of You' by Lionlimb (7 sections)
# ✓ Embedded: 'Can’t Sleep' by Stella Dunai (4 sections)
# ✓ Embedded: 'Centipede' by Wilsen (4 sections)
# ✓ Embedded: 'Dinah' by Sophie Jamieson (1 sections)
# ✓ Embedded: 'Sweetest Heart' by Rachel Bobbitt (5 sections)
# ✓ Embedded: 'Forget her' by EERA (NOR) (6 sections)
# ✓ Embedded: 'FOMO' by Maple Glider (4 sections)
# ✓ Embedded: 'Falling' by Julee Cruise (6 sections)
# ✓ Embedded: 'Fade Into You' by Mazzy Star (5 sections)
# ✓ Embedded: 'Starlust' by Lush (1 sections)
# ✓ Embedded: 'Goodbye' by The Sundays (5 sections)
# ✓ Embedded: 'Andromeda' by Weyes Blood (7 sections)
# ✓ Embedded: 'Floating' by Julee Cruise (7 sections)
# ✓ Embedded: 'Here’s Where the Story Ends' by The Sundays (9 sections)
# ✓ Embedded: 'Light from a Dead Star' by Lush (3 sections)
# ✓ Embedded: 'Levitation' by Beach House (5 sections)
# ✓ Embedded: 'On Earth' by The Sundays (5 sections)
# ✓ Embedded: 'Used to Be' by Beach House (5 sections)
# ✓ Embedded: 'Myth' by Beach House (7 sections)
# ✓ Embedded: 'Wild' by Beach House (7 sections)
# ✓ Embedded: 'Silver Soul' by Beach House (5 sections)
# ✓ Embedded: 'Lovelife' by Lush (8 sections)
# ✓ Embedded: 'Contender' by The Pains of Being Pure at Heart (1 sections)
# ✓ Embedded: 'PPP' by Beach House (7 sections)
# ✓ Embedded: 'A Teenager in Love' by The Pains of Being Pure at Heart (8 sections)
# ✓ Embedded: 'Kinky Love' by Pale Saints (6 sections)
# ✓ Embedded: 'Lazuli' by Beach House (4 sections)
# ✓ Embedded: 'Blue Light' by Mazzy Star (7 sections)
# ✓ Embedded: 'Desire Lines' by Lush (3 sections)
# ✓ Embedded: 'Dreams' by The Cranberries (7 sections)
# ✓ Embedded: 'Into the Night' by Julee Cruise (5 sections)
# ✓ Embedded: 'Young Adult Friction' by The Pains of Being Pure at Heart (5 sections)
# ✓ Embedded: 'Other People' by Beach House (7 sections)
# ✓ Embedded: 'Zebra' by Beach House (6 sections)
# ✓ Embedded: 'Sea, Swallow Me' by Cocteau Twins (1 sections)
# ✓ Embedded: 'Come to Me' by Björk (4 sections)
# ✓ Embedded: 'For Love' by Lush (8 sections)
# ✓ Embedded: 'The Nightingale' by Julee Cruise (6 sections)
# ✓ Embedded: 'Love' by The Sundays (9 sections)
# ✓ Embedded: 'Sunday' by The Cranberries (9 sections)
# ✓ Embedded: 'Fine Friend' by Pale Saints (6 sections)
# ✓ Embedded: 'Say Yes To Heaven' by Lana Del Rey (10 sections)
# ✓ Embedded: 'I’m Not in Love' by Kelsey Lu (10 sections)
# ✓ Embedded: 'Thursday' by Asobi Seksu (5 sections)
# ✓ Embedded: 'Insubstantial' by Pale Saints (1 sections)
# ✓ Embedded: 'Hold On, I’m Comin’' by Sam & Dave (7 sections)
# ✓ Embedded: 'Knock on Wood' by Eddie Floyd (7 sections)
# ✓ Embedded: '(Sittin’ On) The Dock of the Bay' by Otis Redding (8 sections)
# ✓ Embedded: 'Respect' by Aretha Franklin (10 sections)
# ✓ Embedded: 'Sweet Soul Music' by Arthur Conley (9 sections)
# ✓ Embedded: 'Le Freak' by Chic (10 sections)
# ✓ Embedded: 'Learn to Let Go' by The Doobie Brothers (10 sections)
# ✓ Embedded: 'Street Life' by Randy Crawford (1 sections)
# ✓ Embedded: 'Two Grey Rooms (Demo) [2025 Remaster]' by Joni Mitchell (1 sections)
# ✓ Embedded: 'One and Only' by Gabriels (USA) (11 sections)
# ✓ Embedded: 'Clean Up Woman' by Betty Wright (7 sections)
# ✓ Embedded: 'I’m Every Woman' by Chaka Khan (7 sections)
# ✓ Embedded: 'Space Between Us' by Franc Moody (9 sections)
# ✓ Embedded: 'Killing Me Softly with His Song' by Roberta Flack (10 sections)
# ✓ Embedded: 'Chain of Fools' by Aretha Franklin (8 sections)
# ✓ Embedded: 'Simply Beautiful' by Maxwell (1 sections)
# ✓ Embedded: 'The Rubberband Man' by The Spinners (23 sections)
# ✓ Embedded: 'Ain’t No Sunshine' by Betty Wright (1 sections)
# ✓ Embedded: 'Let Not (Your Heart Be Troubled)' by Lady Blackbird (1 sections)
# ✓ Embedded: 'Soul Girl' by Jeanne & The Darlings (8 sections)
# ✓ Embedded: 'Here I Am' by Mary J. Blige (7 sections)
# ✓ Embedded: 'Hypnotized' by Linda Jones (1 sections)
# ✓ Embedded: 'Give Me the Night' by George Benson (10 sections)
# ✓ Embedded: 'Wonderful World' by Otis Redding (1 sections)
# ✓ Embedded: 'I Say a Little Prayer' by Aretha Franklin (9 sections)
# ✓ Embedded: 'Everybody Needs Somebody To Love' by Solomon Burke (4 sections)
# ✓ Embedded: 'Hard Times' by Baby Huey (8 sections)
# ✓ Embedded: 'Think' by Aretha Franklin (10 sections)
# ✓ Embedded: 'So in Love' by Curtis Mayfield (6 sections)
# ✓ Embedded: 'Let It Be' by Aretha Franklin (7 sections)
# ✓ Embedded: 'Rock Your Baby' by George McCrae (11 sections)
# ✓ Embedded: 'After Laughter (Comes Tears)' by Wendy Rene (5 sections)
# ✓ Embedded: 'Give Me The Night' by Randy Crawford (1 sections)
# ✓ Embedded: 'Natural High' by Bloodstone (9 sections)
# ✓ Embedded: 'Son of a Preacher Man' by Aretha Franklin (6 sections)
# ✓ Embedded: 'Bitter' by Ogi (R&B) (12 sections)
# ✓ Embedded: 'Rainy Night in Georgia' by Brook Benton (8 sections)
# ✓ Embedded: 'Hallelujah, I Love Her So' by Ray Charles (7 sections)
# ✓ Embedded: 'Going Back To My Roots' by Richie Havens (1 sections)
# ✓ Embedded: 'Me Myself and I' by De La Soul (12 sections)
# ✓ Embedded: 'Wishing On a Star' by Rose Royce (12 sections)
# ✓ Embedded: 'The Ghetto' by Donny Hathaway (1 sections)
# ✓ Embedded: 'Young Hearts Run Free' by Candi Staton (7 sections)
# ✓ Embedded: 'Move Me No Mountain' by Dionne Warwick (1 sections)
# ✓ Embedded: 'Where Is the Love' by Roberta Flack (7 sections)
# ✓ Embedded: 'Cry to Me' by Solomon Burke (4 sections)
# ✓ Embedded: 'I’ll Be Around' by The Spinners (5 sections)
# ✓ Embedded: 'Let Me Love You' by Mario (10 sections)
# ✓ Embedded: 'Miss Independent' by Ne-Yo (12 sections)
# ✓ Embedded: 'My Boo' by USHER (8 sections)
# ✓ Embedded: 'Dilemma' by Nelly (13 sections)
# ✓ Embedded: 'No Scrubs' by TLC (9 sections)
# ✓ Embedded: 'Because of You' by Ne-Yo (13 sections)
# ✓ Embedded: 'Sexy Love' by Ne-Yo (10 sections)
# ✓ Embedded: 'With You' by Chris Brown (9 sections)
# ✓ Embedded: 'Ride wit Me' by Nelly (9 sections)
# ✓ Embedded: 'Confessions' by USHER (8 sections)
# ✓ Embedded: 'Say Goodbye' by Chris Brown (9 sections)
# ✓ Embedded: 'If I Ain’t Got You' by Alicia Keys (8 sections)
# ✓ Embedded: 'Go on Girl' by Ne-Yo (12 sections)
# ✓ Embedded: 'I Wanna Love You' by Akon (9 sections)
# ✓ Embedded: 'Bad Girl' by USHER (9 sections)
# ✓ Embedded: 'How Do I Breathe' by Mario (9 sections)
# ✓ Embedded: 'Foolish' by Ashanti (10 sections)
# ✓ Embedded: 'Mesmerize' by Ja Rule (11 sections)
# ✓ Embedded: 'Sexy Can I' by Ray J (16 sections)
# ✓ Embedded: 'Yo (Excuse Me Miss)' by Chris Brown (8 sections)
# ✓ Embedded: 'So Sick' by Ne-Yo (9 sections)
# ✓ Embedded: 'Confessions Part II' by USHER (8 sections)
# ✓ Embedded: 'Unfoolish' by Ashanti (9 sections)
# ✓ Embedded: 'Burn' by USHER (7 sections)
# ✓ Embedded: 'One Wish' by Ray J (12 sections)
# ✓ Embedded: 'Don’t Matter' by Akon (9 sections)
# ✓ Embedded: 'Closer' by Ne-Yo (11 sections)
# ✓ Embedded: 'Take a Bow' by Rihanna (10 sections)
# ✓ Embedded: 'I’m Sprung' by T-Pain (9 sections)
# ✓ Embedded: 'So Into You' by Tamia (8 sections)
# ✓ Embedded: 'Buy U A Drank (Shawty Snappin’) (feat. Yung Joc) - Acappella' by T-Pain (9 sections)
# ✓ Embedded: 'Do You' by Ne-Yo (6 sections)
# ✓ Embedded: 'I Need a Girl' by Trey Songz (10 sections)
# ✓ Embedded: 'It Girl' by Jason Derulo (7 sections)
# ✓ Embedded: 'Whatcha Say' by Jason Derulo (12 sections)
# ✓ Embedded: 'Best Love Song' by T-Pain (7 sections)
# ✓ Embedded: 'Take You Down' by Chris Brown (10 sections)
# ✓ Embedded: 'We Ride' by Rihanna (13 sections)
# ✓ Embedded: 'Mad' by Ne-Yo (9 sections)
# ✓ Embedded: 'Smack That' by Akon (12 sections)
# ✓ Embedded: 'Touch My Body' by Mariah Carey (10 sections)
# ✓ Embedded: 'Love Don’t Change' by Jeremih (8 sections)
# ✓ Embedded: 'We Belong Together' by Mariah Carey (6 sections)
# ✓ Embedded: 'In My Head' by Jason Derulo (10 sections)
# ✓ Embedded: 'Love In This Club' by USHER (10 sections)
# ✓ Embedded: 'Hate That I Love You' by Rihanna (8 sections)
# ✓ Embedded: 'U Remind Me' by USHER (9 sections)
# ✓ Embedded: 'Kiss Me Thru The Phone' by Soulja Boy (8 sections)
# ✓ Embedded: 'I Wanna Know' by Joe (10 sections)
# ✓ Embedded: 'Neighbors Know My Name' by Trey Songz (7 sections)
# ✓ Embedded: 'What If' by Jason Derulo (8 sections)
# ✓ Embedded: 'Bed' by J. Holiday (10 sections)
# ✓ Embedded: 'U Got It Bad' by USHER (8 sections)
# ✓ Embedded: 'Ice Box' by Omarion (10 sections)
# ✓ Embedded: 'Forever' by Chris Brown (8 sections)
# ✓ Embedded: 'Me & U' by Cassie (10 sections)
# ✓ Embedded: 'Best I Ever Had' by Drake (7 sections)
# ✓ Embedded: 'Umbrella' by Rihanna (9 sections)
# ✓ Embedded: 'Officially Missing You' by Tamia (8 sections)
# ✓ Embedded: 'Lovers and Friends' by Lil Jon & The East Side Boyz (8 sections)
# ✓ Embedded: 'When You’re Mad' by Ne-Yo (6 sections)
# ✓ Embedded: 'Bust It Baby, Pt. 2' by Plies (8 sections)
# ✓ Embedded: 'Lie About Us' by Avant (11 sections)
# ✓ Embedded: 'I Choose You' by Mario (8 sections)
# ✓ Embedded: 'Rockin’ That Shit' by The-Dream (9 sections)
# ✓ Embedded: 'Did You Wrong' by Pleasure P (7 sections)
# ✓ Embedded: 'Hypnotized' by Plies (8 sections)
# ✓ Embedded: 'I’m a Flirt (Remix)' by R. Kelly (9 sections)
# ✓ Embedded: 'Pullin’ Me Back' by Chingy (7 sections)
# ✓ Embedded: 'Grind With Me' by Pretty Ricky (9 sections)
# ✓ Embedded: 'I Luv Your Girl' by The-Dream (12 sections)
# ✓ Embedded: 'Like You' by Bow Wow (8 sections)
# ✓ Embedded: 'Shawty Is Da Shit' by The-Dream (11 sections)
# ✓ Embedded: 'Rock Wit U (Awww Baby)' by Ashanti (9 sections)
# ✓ Embedded: '4 Minutes' by Avant (8 sections)
# ✓ Embedded: 'Always On Time' by Ja Rule (12 sections)
# ✓ Embedded: 'Slow Down (12" Version)' by Bobby V (11 sections)
# ✓ Embedded: 'Fuck It (I Don’t Want You Back)' by Eamon (9 sections)
# ✓ Embedded: 'In Those Jeans' by Ginuwine (9 sections)
# ✓ Embedded: 'Body on Me' by Ashanti (7 sections)
# ✓ Embedded: 'Motivation' by Kelly Rowland (9 sections)
# ✓ Embedded: 'Your Body' by Pretty Ricky (12 sections)
# ✓ Embedded: 'Unappreciated' by Cherish (8 sections)
# ✓ Embedded: 'Ignition (Remix)' by R. Kelly (12 sections)
# ✓ Embedded: 'Knock You Down' by Keri Hilson (10 sections)
# ✓ Embedded: 'Are You That Somebody?' by Aaliyah (9 sections)
# ✓ Embedded: 'Too Close' by Next (12 sections)
# ✓ Embedded: 'You' by Lloyd (12 sections)
# ✓ Embedded: 'Can’t Help But Wait' by Trey Songz (10 sections)
# ✓ Embedded: 'The Boy Is Mine' by Brandy (9 sections)
# ✓ Embedded: 'You Make Me Wanna...' by USHER (9 sections)
# ✓ Embedded: '7 Days' by Craig David (9 sections)
# ✓ Embedded: 'Everytime I Close My Eyes' by Babyface (9 sections)
# ✓ Embedded: 'Pony' by Ginuwine (7 sections)
# ✓ Embedded: 'On Bended Knee' by Boyz II Men (8 sections)
# ✓ Embedded: 'Nice & Slow (Radio Version)' by USHER (8 sections)
# ✓ Embedded: 'I’ll Make Love to You' by Boyz II Men (8 sections)
# ✓ Embedded: 'All My Life' by K-Ci & JoJo (8 sections)
# ✓ Embedded: 'Back at One' by Brian McKnight (6 sections)
# ✓ Embedded: 'Family Affair' by Mary J. Blige (7 sections)
# ✓ Embedded: 'Work It' by Missy Elliott (10 sections)
# ✓ Embedded: 'Waterfalls' by TLC (6 sections)
# ✓ Embedded: 'Bleeding Love' by Leona Lewis (12 sections)
# ✓ Embedded: 'Ms. Jackson' by OutKast (9 sections)
# ✓ Embedded: 'Let Me Blow Ya Mind' by Eve (7 sections)
# ✓ Embedded: 'Caught Up' by USHER (12 sections)
# ✓ Embedded: 'Right Thurr' by Chingy (10 sections)
# ✓ Embedded: 'Roses' by OutKast (8 sections)
# ✓ Embedded: '1, 2 Step' by Ciara (10 sections)
# ✓ Embedded: 'Fantasy' by Mariah Carey (8 sections)
# ✓ Embedded: 'Sure Thing' by Miguel (10 sections)
# ✓ Embedded: 'CUFF IT' by Beyoncé (11 sections)
# ✓ Embedded: 'Die For You (Remix)' by The Weeknd (8 sections)
# ✓ Embedded: 'Under the Influence' by Chris Brown (10 sections)
# ✓ Embedded: 'Kill Bill' by SZA (8 sections)
# ✓ Embedded: 'People' by Libianca (9 sections)
# ✓ Embedded: 'Snooze' by SZA (8 sections)
# ✓ Embedded: 'Blinding Lights' by The Weeknd (11 sections)
# ✓ Embedded: 'Mist' by Soul Blind (1 sections)
# ✓ Embedded: 'Beemomug' by Deafcult (4 sections)
# ✓ Embedded: 'Swirl' by Soul Blind (3 sections)
# ✓ Embedded: 'C.A.' by Grivo (1 sections)
# ✓ Embedded: 'Youngest Daughter' by Superheaven (6 sections)
# ✓ Embedded: 'Phantom Pool' by Soul Blind (5 sections)
# ✓ Embedded: 'Yellow' by Leaving Time (1 sections)
# ✓ Embedded: 'Night Tryst' by Narrow Head (4 sections)
# ✓ Embedded: 'Saturday Saviour' by Failure (6 sections)
# ✓ Embedded: 'Necrosis' by Narrow Head (4 sections)
# ✓ Embedded: 'Stay' by Leaving Time (2 sections)
# ✓ Embedded: 'Ease' by Whirr (4 sections)
# ✓ Embedded: 'Nancy France' by Narrow Head (4 sections)
# ✓ Embedded: 'Jacaranda' by Modern Color (3 sections)
# ✓ Embedded: 'Still' by Leaving Time (1 sections)
# ✓ Embedded: 'Wallflower' by Narrow Head (4 sections)
# ✓ Embedded: 'H.D.C.' by Grivo (4 sections)
# ✓ Embedded: 'July the Fourth' by Nothing (Band) (1 sections)
# ✓ Embedded: 'Bloom' by Leaving Time (1 sections)
# ✓ Embedded: 'Pissing Off the Neighbors' by Cursetheknife (2 sections)
# ✓ Embedded: 'Stay' by Narrow Head (5 sections)
# ✓ Embedded: 'Relay' by Trauma Ray (7 sections)
# ✓ Embedded: 'Crawling Into You' by Soul Blind (4 sections)
# ✓ Embedded: 'Falling Asleep' by Soul Blind (4 sections)
# ✓ Embedded: 'WMD' by Trauma Ray (5 sections)
# ✓ Embedded: 'Glow' by Slow Crush (6 sections)
# ✓ Embedded: 'Cool In Motion' by Narrow Head (6 sections)
# ✓ Embedded: 'Cyanide' by Soul Blind (4 sections)
# ✓ Embedded: 'This, If Anything' by Fleshwater (8 sections)
# ✓ Embedded: 'Press' by Whirr (1 sections)
# ✓ Embedded: 'Solstice' by Trauma Ray (4 sections)
# ✓ Embedded: 'Far Removed' by Narrow Head (6 sections)
# ✓ Embedded: 'Wavelength' by Whirr (1 sections)
# ✓ Embedded: 'Cherry Waves' by Deftones (7 sections)
# ✓ Embedded: 'Be Quiet and Drive (Far Away)' by Deftones (7 sections)
# ✓ Embedded: 'Change (In the House of Flies)' by Deftones (9 sections)
# ✓ Embedded: 'The Spell of Mathematics' by Deftones (6 sections)
# ✓ Embedded: 'Pompeji' by Deftones (8 sections)
# ✓ Embedded: 'Prayers / Triangles' by Deftones (7 sections)
# ✓ Embedded: 'Hearts / Wires' by Deftones (6 sections)
# ✓ Embedded: 'Phantom Bride' by Deftones (6 sections)
# ✓ Embedded: 'Entombed' by Deftones (6 sections)
# ✓ Embedded: 'Tempest' by Deftones (10 sections)
# ✓ Embedded: 'Rosemary' by Deftones (8 sections)
# ✓ Embedded: 'What Happened to You?' by Deftones (8 sections)
# ✓ Embedded: 'Sextape' by Deftones (7 sections)
# ✓ Embedded: 'This Place Is Death' by Deftones (7 sections)
# ✓ Embedded: 'Hole in the Earth' by Deftones (7 sections)
# ✓ Embedded: 'Beware' by Deftones (9 sections)
# ✓ Embedded: 'Blvd. Nights' by Team Sleep (4 sections)
# ✓ Embedded: 'Ashtray' by Narrow Head (4 sections)
# ✓ Embedded: 'Make It Hurt' by Narrow Head (5 sections)
# ✓ Embedded: 'Kimdracula' by Deftones (7 sections)
# ✓ Embedded: 'Rivière' by Deftones (3 sections)
# ✓ Embedded: 'Minerva' by Deftones (7 sections)
# ✓ Embedded: 'Moana' by Deftones (6 sections)
# ✓ Embedded: 'Rx Queen' by Deftones (9 sections)
# ✓ Embedded: 'Knife Prty' by Deftones (6 sections)
# ✓ Embedded: 'A Sad Cartoon' by Loathe (7 sections)
# ✓ Embedded: 'Screaming' by Loathe (7 sections)
# ✓ Embedded: 'Mumble' by Whirr (1 sections)
# ✓ Embedded: 'Risk' by Deftones (7 sections)
# ✓ Embedded: 'Is It Really You?' by Loathe (6 sections)
# ✓ Embedded: '976-EVIL' by Deftones (7 sections)
# ✓ Embedded: '20 seconds : 20 hours' by Vein.fm (4 sections)
# ✓ Embedded: 'Younger Than You' by Whirr (5 sections)
# ✓ Embedded: 'Linda Claire' by Fleshwater (5 sections)
# ✓ Embedded: 'Blank' by Glare (2 sections)
# ✓ Embedded: 'Headless' by Deftones (12 sections)
# ✓ Embedded: 'Nervous Habits' by Narrow Head (7 sections)
# ✓ Embedded: 'Undone' by Failure (7 sections)
# ✓ Embedded: 'Another Space Song' by Failure (5 sections)
# ✓ Embedded: 'The Same Place' by Centaur (1 sections)
# ✓ Embedded: 'Pale' by Modern Color (4 sections)
# ✓ Embedded: 'Covet' by Basement (7 sections)
# ✓ Embedded: 'Mein' by Deftones (7 sections)
# ✓ Embedded: 'In Slow Time' by Narrow Head (4 sections)
# ✓ Embedded: 'In on It' by Superheaven (8 sections)
# ✓ Embedded: 'Rolling Out the Red Carpet' by Hail the Sun (2 sections)
# ✓ Embedded: 'Blue Line Baby' by Nothing (Band) (6 sections)
# ✓ Embedded: 'Two-Way Mirror' by Loathe (6 sections)
# ✓ Embedded: 'Mellow' by Whirr (1 sections)
# ✓ Embedded: 'Nodding Off' by Narrow Head (5 sections)
# ✓ Embedded: 'Lily' by Gleemer (4 sections)
# ✓ Embedded: 'Whole' by Basement (6 sections)
# ✓ Embedded: 'Digital Bath' by Deftones (6 sections)
# ✓ Embedded: 'Rose Cold' by Whirr (1 sections)
# ✓ Embedded: 'Dumb' by Pretty Sick (6 sections)
# ✓ Embedded: 'Paranoid Hands' by Narrow Head (5 sections)
# ✓ Embedded: 'Liar’s Love' by Title Fight (1 sections)
# ✓ Embedded: 'Come Down' by Gleemer (1 sections)
# ✓ Embedded: 'Famine Asylum' by Nothing (Band) (5 sections)
# ✓ Embedded: 'Star Thistle Blossom' by Milly (Band) (6 sections)
# ✓ Embedded: 'Stuck on You' by Failure (6 sections)
# ✓ Embedded: 'What Was Really Said' by Fleshwater (4 sections)
# ✓ Embedded: 'On and Off' by Modern Color (6 sections)
# ✓ Embedded: 'In Dreams' by Cursetheknife (1 sections)
# ✓ Embedded: 'Alley Cat' by All under heaven (4 sections)
# ✓ Embedded: 'Ataraxia' by Team Sleep (5 sections)
# ✓ Embedded: 'In Your Way' by Gleemer (5 sections)
# ✓ Embedded: 'The Pod' by Hum (6 sections)
# ✓ Embedded: 'Leadings On' by Gleemer (6 sections)
# ✓ Embedded: 'Hole' by Heavenward (6 sections)
# ✓ Embedded: 'Talking Secret' by Milly (Band) (1 sections)
# ✓ Embedded: 'Uncover' by Narrow Head (6 sections)
# ✓ Embedded: 'Shallow Breath' by Slow Crush (5 sections)
# ✓ Embedded: 'Elude' by Grivo (1 sections)
# ✓ Embedded: 'Dread' by Modern Color (9 sections)
# ✓ Embedded: 'Crawling' by Slow Joy (1 sections)
# ✓ Embedded: 'Golden Goddess' by Slow Joy (1 sections)
# ✓ Embedded: 'Next to Nothing' by Superheaven (1 sections)
# ✓ Embedded: 'Room' by Superheaven (1 sections)
# ✓ Embedded: 'Brush Back' by Gleemer (6 sections)
# ✓ Embedded: 'The Hellfire Club' by Thornhill (1 sections)
# ✓ Embedded: 'Blue Velvet' by Thornhill (1 sections)
# ✓ Embedded: 'Varsity Hearts' by Thornhill (7 sections)
# ✓ Embedded: 'Heroine' by Thornhill (7 sections)
# ✓ Embedded: 'Opiate' by Modern Color (7 sections)
# ✓ Embedded: 'Pollen' by Superbloom (1 sections)
# ✓ Embedded: 'Flesh' by Sleepwalk (4 sections)
# ✓ Embedded: 'Starve' by Trauma Ray (4 sections)
# ✓ Embedded: 'Ooze' by Sleepwalk (6 sections)
# ✓ Embedded: 'Heading for the Door' by No Sun (1 sections)
# ✓ Embedded: 'Show Me the Real You' by Moodring (7 sections)
# ✓ Embedded: 'Disintegrate' by Moodring (7 sections)
# ✓ Embedded: 'Circles of Hell' by Greet Death (1 sections)
# ✓ Embedded: 'sometimes' by my bloody valentine (4 sections)
# ✓ Embedded: 'Sea of Worry' by Have a Nice Life (5 sections)
# ✓ Embedded: 'Dracula Bells' by Have a Nice Life (5 sections)
# ✓ Embedded: 'Pissant (Siamese Sessions Rough Mix)' by The Smashing Pumpkins (9 sections)
# ✓ Embedded: 'Siamese Dream (Broadway Rehearsals Demo)' by The Smashing Pumpkins (10 sections)
# ✓ Embedded: 'Where the Light Takes Us' by Blanket (1 sections)
# ✓ Embedded: 'Now, Life is Living You' by Modern Color (5 sections)
# ✓ Embedded: 'Nurture' by Thornhill (8 sections)
# ✓ Embedded: 'Passed Down' by Gleemer (6 sections)
# ✓ Embedded: 'Backlog' by Gleemer (4 sections)
# ✓ Embedded: 'Public secret' by Erick Estrada (7 sections)
# ✓ Embedded: 'If Only You Were Human' by Estrada (9 sections)
# ✓ Embedded: 'such.a.shame' by Static Dress (6 sections)
# ✓ Embedded: 'Autre temps' by Alcest (5 sections)
# ✓ Embedded: 'Savia' by Soen (9 sections)
# ✓ Embedded: 'L’île des morts' by Alcest (1 sections)
# ✓ Embedded: 'Attempt 8' by Static Dress (3 sections)
# ✓ Embedded: 'Red Light Gossip' by Moodring (7 sections)
# ✓ Embedded: 'Peel' by Moodring (7 sections)
# ✓ Embedded: 'Stargazer' by Moodring (6 sections)
# ✓ Embedded: 'Head in the Clouds' by Moodring (8 sections)
# ✓ Embedded: 'Come and Go' by Moodring (1 sections)
# ✓ Embedded: 'Gasoline' by Moodring (1 sections)
# ✓ Embedded: 'Pink Maggit' by Deftones (5 sections)
# ✓ Embedded: 'Zero Day' by Nothing (Band) (1 sections)
# ✓ Embedded: 'Plastic Migraine' by Nothing (Band) (1 sections)
# ✓ Embedded: 'Sapphire' by Alcest (1 sections)
# ✓ Embedded: 'Don’t Suffer Alone' by All under heaven (5 sections)
# ✓ Embedded: 'See You Sacred' by ASkySoBlack (1 sections)
# ✓ Embedded: 'T.W.I.N.' by Narrow Head (4 sections)
# ✓ Embedded: 'Send the Pain Below' by Chevelle (6 sections)
# ✓ Embedded: 'Telomeres' by Sleep Token (5 sections)
# ✓ Embedded: 'Needles and Pins' by Deftones (7 sections)
# ✓ Embedded: 'Good Morning Beautiful' by Deftones (7 sections)
# ✓ Embedded: 'Deathblow' by Deftones (7 sections)
# ✓ Embedded: 'Bloody Cape' by Deftones (6 sections)
# ✓ Embedded: 'Pink Cellphone' by Deftones (12 sections)
# ✓ Embedded: 'Romantic Dreams' by Deftones (13 sections)
# ✓ Embedded: 'Leathers' by Deftones (8 sections)
# ✓ Embedded: 'Xenon' by Deftones (6 sections)
# ✓ Embedded: '(L)MIRL' by Deftones (10 sections)
# ✓ Embedded: 'Ceremony' by Deftones (7 sections)
# ✓ Embedded: 'Ohms' by Deftones (6 sections)
# ✓ Embedded: 'Head in the Ceiling Fan' by Title Fight (3 sections)
# ✓ Embedded: 'Murder Your Memory' by Title Fight (1 sections)
# ✓ Embedded: 'Symmetry' by Title Fight (5 sections)
# ✓ Embedded: 'Hypernight' by Title Fight (6 sections)
# ✓ Embedded: 'Build a Bridge' by Limp Bizkit (8 sections)
# ✓ Embedded: 'When It Comes' by Incubus (9 sections)
# ✓ Embedded: 'Stellar' by Incubus (7 sections)
# ✓ Embedded: 'Blood on the Ground' by Incubus (7 sections)
# ✓ Embedded: 'Mascara' by Deftones (5 sections)
# ✓ Embedded: 'Hexagram' by Deftones (7 sections)
# ✓ Embedded: 'When Girls Telephone Boys' by Deftones (8 sections)
# ✓ Embedded: 'You’ve Seen the Butcher' by Deftones (9 sections)
# ✓ Embedded: 'Diamond Eyes' by Deftones (8 sections)
# ✓ Embedded: 'Crescent-Shaped Depression' by Title Fight (4 sections)
# ✓ Embedded: 'Desperately Seeking Answers' by All under heaven (6 sections)
# ✓ Embedded: 'clean.' by Static Dress (8 sections)
# ✓ Embedded: 'Chloroform' by Nothing (Band) (6 sections)
# ✓ Embedded: 'Empty Rooms' by Modern Color (6 sections)
# ✓ Embedded: 'Hanging Around' by Basement (2 sections)
# ✓ Embedded: 'Brain Dead' by Narrow Head (4 sections)
# ✓ Embedded: 'Bumblebee' by Sleepwalk (1 sections)
# ✓ Embedded: 'New Motion' by Modern Color (6 sections)
# ✓ Embedded: 'Monolove' by HEALS (1 sections)
# ✓ Embedded: 'Star Roving' by Slowdive (5 sections)
# ✓ Embedded: '12th House' by Narrow Head (1 sections)
# ✓ Embedded: 'Hard To Swallow' by Narrow Head (6 sections)
# ✓ Embedded: 'For The Kill' by Life on Venus (1 sections)
# ✓ Embedded: 'Your Skull Is Red (Live)' by Team Sleep (3 sections)
# ✓ Embedded: 'Poor Aileen' by Superheaven (8 sections)
# ✓ Embedded: 'I Hate the Flowers' by Nothing (Band) (1 sections)
# ✓ Embedded: 'I Let It in and It Took Everything...' by Loathe (1 sections)
# ✓ Embedded: 'Xerces' by Deftones (5 sections)
# ...
# ✓ Embedded: 'It’s a Fire' by Portishead (4 sections)
# ✓ Embedded: 'Slowly' by Max sedgley (1 sections)
# ✓ Embedded: 'Throw It All Away' by Zero 7 (8 sections)
# ✓ Embedded: 'Playground Love' by Air (4 sections)
# ✓ Embedded: 'Pop Art Blue' by Zero 7 (1 sections)
# ✓ Embedded: 'Lonely Dancer' by Tricky (1 sections)
# ✓ Embedded: 'This Fine Social Scene' by Zero 7 (6 sections)
# ✓ Embedded: 'Sour Times' by Portishead (9 sections)
# ✓ Embedded: 'Protection' by Massive Attack (10 sections)
# ✓ Embedded: 'Slow Down' by Morcheeba (1 sections)
# ✓ Embedded: 'Mad About You' by Hooverphonic (8 sections)
# ✓ Embedded: 'Tuna Fish' by Emilíana Torrini (1 sections)
# ✓ Embedded: 'Why?' by GusGus (1 sections)
# ✓ Embedded: 'Distractions' by Zero 7 (5 sections)
# ✓ Embedded: 'Biscuit' by Portishead (8 sections)
# ✓ Embedded: 'Could It Be Real (Remix)' by Soma Sonic (1 sections)
# ✓ Embedded: 'Nothing Left to Lose' by 8mm (7 sections)
# ✓ Embedded: 'Road to Somewhere' by Goldfrapp (5 sections)
# ✓ Embedded: 'Chemistry and Math' by Flunk (1 sections)
# ✓ Embedded: 'This Isn’t the Place' by Nine Inch Nails (1 sections)
# ✓ Embedded: 'Over' by Portishead (9 sections)
# ✓ Embedded: 'Country Livin’ (The World I Know)' by Esthero (7 sections)
# ✓ Embedded: 'Turn Around' by Terranova (1 sections)
# ✓ Embedded: 'Simplicity (original)' by Soma Sonic (1 sections)
# ✓ Embedded: 'Shadows Crawl' by Torii Wolf (6 sections)
# ✓ Embedded: 'Night Drive Loneliness' by Garbage (10 sections)
# ✓ Embedded: 'Trick of time' by Dubphonic (1 sections)
# ✓ Embedded: 'Bloodstain' by UNKLE (7 sections)
# ✓ Embedded: 'Petrified' by Flunk (1 sections)
# ✓ Embedded: 'Blind My Mind' by Flunk (1 sections)
# ✓ Embedded: 'Puppy Toy' by Tricky (1 sections)
# ✓ Embedded: 'Like a Stone' by Tricky (4 sections)
# ✓ Embedded: 'Anything' by Martina Topley-Bird (1 sections)
# ✓ Embedded: 'Ocean City Girl' by Ivy (1 sections)
# ✓ Embedded: 'Better Things' by Massive Attack (6 sections)
# ✓ Embedded: 'Flowers and Silence' by Sneaker Pimps (1 sections)
# ✓ Embedded: 'Home' by Zero 7 (1 sections)
# ✓ Embedded: 'I Might Be Wrong' by Radiohead (8 sections)
# ✓ Embedded: 'Psychobabble' by Frou Frou (12 sections)
# ✓ Embedded: 'Beat' by Bowery Electric (3 sections)
# ✓ Embedded: 'Abnormally Attracted to Sin' by Tori Amos (7 sections)
# ✓ Embedded: 'Hatchet' by Archive (1 sections)
# ✓ Embedded: 'Kites' by Submotion Orchestra (1 sections)
# ✓ Embedded: 'Daydream in Blue (Acoustic)' by I Monster (7 sections)
# ✓ Embedded: 'Pit Stop (Take Me Home)' by Lovage (6 sections)
# ✓ Embedded: 'Comatose' by Cinephile (4 sections)
# ✓ Embedded: 'Karma police' by Flunk (1 sections)
# ✓ Embedded: 'Miss World' by Flunk (1 sections)
# ✓ Embedded: 'Breathe Me Right In (Live)' by Tricky (3 sections)
# ✓ Embedded: 'Missing Piece' by Recoil (8 sections)
# ✓ Embedded: 'Angel' by 8mm (8 sections)
# ✓ Embedded: 'Too Tough To Die' by Martina Topley-Bird (1 sections)
# ✓ Embedded: 'Out, Damn Light' by Sofa Surfers (1 sections)
# ✓ Embedded: 'Butterfly Caught' by Massive Attack (3 sections)
# ✓ Embedded: 'Army of Me' by Björk (6 sections)
# ✓ Embedded: 'Melancholia (Bonus)' by 40 winks (1 sections)
# ✓ Embedded: 'Anyone Else' by Puracane (1 sections)
# ✓ Embedded: 'My Violent Heart' by Nine Inch Nails (6 sections)
# ✓ Embedded: 'Evolution Revolution Love' by Tricky (8 sections)
# ✓ Embedded: 'Space Lust ( In The Space Dust )' by Anjali (1 sections)
# ✓ Embedded: 'Superheroes' by Esthero (1 sections)
# ✓ Embedded: 'What Your Soul Sings' by Massive Attack (6 sections)
# ✓ Embedded: 'Old Artist' by Archive (1 sections)
# ✓ Embedded: 'Sick' by Sneaker Pimps (6 sections)
# ✓ Embedded: 'Girl I Love You' by Massive Attack (5 sections)
# ✓ Embedded: 'Under The Gun' by Supreme Beings Of Leisure (1 sections)
# ✓ Embedded: 'Suffocated Love' by Tricky (8 sections)
# ✓ Embedded: 'Never The Same' by Supreme Beings Of Leisure (1 sections)
# ✓ Embedded: 'Fade Out' by Naomi (1 sections)
# ✓ Embedded: 'Rabbit In Your Headlights' by UNKLE (8 sections)
# ✓ Embedded: 'Floating World' by Bowery Electric (2 sections)
# ✓ Embedded: 'Risingson' by Massive Attack (7 sections)
# ✓ Embedded: 'The Well (Remix)' by Soma Sonic (1 sections)
# ✓ Embedded: 'Give It Up' by 8mm (6 sections)
# ✓ Embedded: 'Prosiac' by Elsiane (1 sections)
# ✓ Embedded: 'Nothing but Trouble' by Phantogram (6 sections)
# ✓ Embedded: 'Karmacoma (Portishead Experience)' by Massive Attack (6 sections)
# ✓ Embedded: 'Sand' by Puracane (1 sections)
# ✓ Embedded: 'Things You Should Leave Alone' by Puracane (1 sections)
# ✓ Embedded: 'Name Taken' by Massive Attack (8 sections)
# ✓ Embedded: 'Tape Loop' by Morcheeba (5 sections)
# ✓ Embedded: 'Pure Heart' by Martina Topley-Bird (1 sections)
# ✓ Embedded: 'Howling' by Morcheeba (1 sections)
# ✓ Embedded: 'So Few Words' by Archive (5 sections)
# ✓ Embedded: 'Across the Stream' by Elsiane (1 sections)
# ✓ Embedded: 'As I moved on' by Blue Foundation (1 sections)
# ✓ Embedded: 'Black Steel' by Tricky (1 sections)
# ✓ Embedded: 'Survivalism' by Nine Inch Nails (7 sections)
# ✓ Embedded: 'End Of Our Days' by Archive (1 sections)
# ✓ Embedded: 'Humming' by Portishead (6 sections)
# ✓ Embedded: 'If Only I Knew' by Tricky (1 sections)
# ✓ Embedded: 'Bullets' by Archive (10 sections)
# ✓ Embedded: 'Free' by Thievery Corporation (1 sections)
# ✓ Embedded: 'Controlling Crowds' by Archive (10 sections)
# ✓ Embedded: 'Naked Eye' by Luscious Jackson (11 sections)
# ✓ Embedded: 'Darkroom' by Archive (3 sections)
# ✓ Embedded: 'Tearz' by El Michels Affair (1 sections)
# ✓ Embedded: 'Life in Mono' by Mono (Duo) (5 sections)
# ✓ Embedded: 'Deaf' by Just Mustard (1 sections)
# ✓ Embedded: 'Tomorrow Comes Today' by Gorillaz (6 sections)
# ✓ Embedded: 'Drifting' by Recoil (8 sections)
# ✓ Embedded: 'I Am' by Airlock (1 sections)
# ✓ Embedded: 'Till The Clouds Clear' by Lamb (UK) (1 sections)
# ✓ Embedded: 'Colours' by Torii Wolf (7 sections)
# ✓ Embedded: 'Man Next Door' by Massive Attack (9 sections)
# ✓ Embedded: 'Arm’s Length' by UNKLE (6 sections)
# ✓ Embedded: 'Red Morning' by Devics (9 sections)
# ✓ Embedded: 'Boo' by Just Mustard (1 sections)
# ✓ Embedded: 'Bela Lugosi’s Dead' by Nouvelle Vague (1 sections)
# ✓ Embedded: 'Nobody Else' by Lamb (UK) (1 sections)
# ✓ Embedded: 'Undenied' by Portishead (6 sections)
# ✓ Embedded: 'Ritual Spirit' by Massive Attack (4 sections)
# ✓ Embedded: 'Numb' by Archive (1 sections)
# ✓ Embedded: 'Gold' by Hugo Kant (1 sections)
# ✓ Embedded: 'Extreme Ways' by Moby (6 sections)
# ✓ Embedded: 'Who am i' by Peace Orchestra (1 sections)
# ✓ Embedded: 'Strange Love' by Koop (1 sections)
# ✓ Embedded: 'Love Show' by Skye (9 sections)
# ✓ Embedded: 'What Else Is There?' by Röyksopp (2 sections)
# ✓ Embedded: 'Beautiful Drug' by Thievery Corporation (1 sections)
# ✓ Embedded: 'Lying Peacefully' by Pepe Deluxé (1 sections)
# ✓ Embedded: 'Electric Light' by PJ Harvey (3 sections)
# ✓ Embedded: 'Four in the Morning' by Ivy (1 sections)
# ✓ Embedded: 'Port' by ​bdrmm (1 sections)
# ✓ Embedded: 'Stained' by Blue Foundation (1 sections)
# ✓ Embedded: 'One Love Karma' by Morcheeba (1 sections)
# ✓ Embedded: 'Cowboys' by Portishead (7 sections)
# ✓ Embedded: 'Overcome' by Tricky (8 sections)
# ✓ Embedded: 'New Stole' by Tricky (5 sections)
# ✓ Embedded: 'Trigger Hippie' by Morcheeba (6 sections)
# ✓ Embedded: 'Elysium' by Portishead (6 sections)
# ✓ Embedded: 'Give' by Tori Amos (6 sections)
# ✓ Embedded: 'Common sense' by Flunk (1 sections)
# ✓ Embedded: 'Take My Head' by Archive (1 sections)
# ✓ Embedded: 'Blue Monday' by Flunk (1 sections)
# ✓ Embedded: 'She Doesn’t Live Here Anymore' by Jay-Jay Johanson (1 sections)
# ✓ Embedded: 'Wasted Early Sunday Morning' by Sneaker Pimps (1 sections)
# ✓ Embedded: 'Silent Spring' by Massive Attack (2 sections)
# ✓ Embedded: 'Black Sheep' by Sneaker Pimps (6 sections)
# ✓ Embedded: 'Lightning Field' by Sneaker Pimps (1 sections)
# ✓ Embedded: 'Six Seven Times' by Flunk (1 sections)
# ✓ Embedded: 'Beautiful Friend' by Cranes (UK) (3 sections)
# ✓ Embedded: 'Slowly' by Waldeck (1 sections)
# ✓ Embedded: 'Truth From Fiction' by Supreme Beings Of Leisure (1 sections)
# ✓ Embedded: 'Demons in the Scenery' by Second Person (7 sections)
# ✓ Embedded: 'Lusty' by Lamb (UK) (1 sections)
# ✓ Embedded: 'Bloodstream' by Stateless (1 sections)
# ✓ Embedded: 'Spin Spin Sugar (Radio Edit)' by Sneaker Pimps (7 sections)
# ✓ Embedded: 'Game' by Martina Topley-Bird (1 sections)
# ✓ Embedded: 'Army of Me (Masseymix)' by Björk (1 sections)
# ✓ Embedded: 'Running Wild' by Tricky (6 sections)
# ✓ Embedded: 'Honestly OK' by Dido (5 sections)
# ✓ Embedded: 'A Brain in a Bottle' by Thom Yorke (6 sections)
# ✓ Embedded: 'Today' by MARTA (7 sections)
# ✓ Embedded: 'Pumpkin (Reincarnated)' by Tricky (1 sections)
# ✓ Embedded: 'All That is Thirst' by Pati Yang (5 sections)
# ✓ Embedded: 'Peculiar' by Vanessa Daou (6 sections)
# ✓ Embedded: 'Lights' by Archive (1 sections)
# ✓ Embedded: 'The Crown' by Archive (3 sections)
# ✓ Embedded: 'Jackie Cane' by Hooverphonic (5 sections)
# ✓ Embedded: 'Heaven' by I Monster (4 sections)
# ✓ Embedded: 'Swollen' by Bent (1 sections)
# ✓ Embedded: 'Leave Me Alone' by Natalie Imbruglia (8 sections)
# ✓ Embedded: 'Wild' by Poe (1 sections)
# ✓ Embedded: 'Damaged (Redemption Extended Version)' by Plumb (1 sections)
# ✓ Embedded: 'Eden' by Hooverphonic (4 sections)
# ✓ Embedded: 'Vinegar & Salt' by Hooverphonic (5 sections)
# ✓ Embedded: 'The Truth' by Handsome Boy Modeling School (6 sections)
# ✓ Embedded: 'Heaven' by Lamb (UK) (1 sections)
# ✓ Embedded: 'Gold' by Archive (1 sections)
# ✓ Embedded: 'Electro Shock Faders' by Hooverphonic (5 sections)
# ✓ Embedded: 'Speed Of Light' by Alphawezen (1 sections)
# ✓ Embedded: 'Crush' by Natalie Walker (1 sections)
# ✓ Embedded: 'Just Enough' by Terranova (1 sections)
# ✓ Embedded: 'For the Damaged Coda' by Blonde Redhead (2 sections)
# ✓ Embedded: 'Cold Water Music' by Aim (1 sections)
# ✓ Embedded: 'With You In My Head' by UNKLE (8 sections)
# ✓ Embedded: 'Miss' by Erika de Casier (5 sections)
# ✓ Embedded: 'Sunday (The Day Before My Birthday)' by Moby (8 sections)
# ✓ Embedded: 'In This World' by Moby (7 sections)
# ✓ Embedded: 'Hollow' by Tricky (1 sections)
# ✓ Embedded: 'Every Breath You Take' by Karen Souza (8 sections)
# ✓ Embedded: 'Don’t speak' by Sarah Menescal (1 sections)
# ✓ Embedded: 'Smooth Operator' by Mario Biondi (10 sections)
# ✓ Embedded: 'Runaway' by Mack H.D & Bolu Ajibade (1 sections)
# ✓ Embedded: 'Monalisa' by Lojay (6 sections)
# ✓ Embedded: 'Rush' by Ayra Starr (10 sections)
# ✓ Embedded: 'Peru' by Fireboy DML (10 sections)
# ✓ Embedded: 'International Lovin' by Mack H.D & Princess Wonda (1 sections)
# ✓ Embedded: 'Soweto (with Don Toliver, Rema, Tempoe)' by Victony (8 sections)
# ✓ Embedded: 'soso' by Omah Lay (5 sections)
# ✓ Embedded: 'In My Bed' by Rotimi (12 sections)
# ✓ Embedded: 'STEADILY' by Mack H.D (7 sections)
# ✓ Embedded: 'KU LO SA (A COLORS SHOW)' by Oxlade (7 sections)
# ✓ Embedded: '​love nwantiti (ah ah ah)' by CKay (9 sections)
# ✓ Embedded: 'Sip (Alcohol)' by Joeboy (8 sections)
# ✓ Embedded: 'Baby (Is it a Crime)' by Rema (8 sections)
# ✓ Embedded: 'City Boys' by Burna Boy (8 sections)
# ✓ Embedded: 'PRITI PRITI' by Mack H.D & Kobi Jonz (1 sections)
# ✓ Embedded: 'Last Last' by Burna Boy (5 sections)
# ✓ Embedded: 'MMS' by Asake (6 sections)
# ✓ Embedded: 'Truth or Dare' by Tyla (8 sections)
# ✓ Embedded: 'Bad Vibes' by Ayra Starr (9 sections)
# ✓ Embedded: 'emiliana' by CKay (7 sections)
# ✓ Embedded: 'SHE BE' by Mack H.D (1 sections)
# ✓ Embedded: 'Isolated' by Mack H.D (1 sections)
# ✓ Embedded: 'Working II' by Keith Sweat (10 sections)
# ✓ Embedded: 'Commas' by Ayra Starr (8 sections)
# ✓ Embedded: 'Bend' by Wizkid (7 sections)
# ✓ Embedded: 'Moving' by Omah Lay (8 sections)
# ✓ Embedded: 'Ngozi' by Crayon (NGA) (1 sections)
# ✓ Embedded: 'With You' by Davido (5 sections)
# ✓ Embedded: 'Shake It To The Max (FLY) [Remix]' by MOLIY (15 sections)
# ✓ Embedded: 'Kese (Dance)' by Wizkid (7 sections)
# ✓ Embedded: 'Ta Ta Ta' by Bayanni (8 sections)
# ✓ Embedded: 'Soundgasm' by Rema (7 sections)
# ✓ Embedded: 'Cough (Odo)' by Kizz Daniel (10 sections)
# ✓ Embedded: 'Playboy' by Fireboy DML (7 sections)
# ✓ Embedded: 'FEEL' by Davido (6 sections)
# ✓ Embedded: 'It’s Plenty' by Burna Boy (8 sections)
# ✓ Embedded: 'Charm' by Rema (9 sections)
# ✓ Embedded: 'Asiwaju' by Ruger (8 sections)
# ✓ Embedded: 'Bandana' by Fireboy DML (7 sections)
# ✓ Embedded: 'If' by Davido (10 sections)
# ✓ Embedded: 'Last Heartbreak Song' by Ayra Starr (6 sections)
# ✓ Embedded: 'On the Low' by Burna Boy (8 sections)
# ✓ Embedded: 'understand' by Omah Lay (8 sections)
# ✓ Embedded: 'N’y pense plus' by Tayc (8 sections)
# ✓ Embedded: 'High' by Adekunle Gold (8 sections)
# ✓ Embedded: 'Fall' by Davido (12 sections)
# ✓ Embedded: 'No Wahala' by 1da Banton (6 sections)
# ✓ Embedded: 'Drogba (Joanna)' by Afro B (10 sections)
# ✓ Embedded: 'Shake Body' by Skales (12 sections)
# ✓ Embedded: 'Mad Over You' by Runtown (10 sections)
# ✓ Embedded: 'Le temps' by Tayc (7 sections)
# ✓ Embedded: 'Joro' by Wizkid (9 sections)
# ✓ Embedded: 'Copines' by Aya Nakamura (9 sections)
# ✓ Embedded: 'D O D O' by Tayc (10 sections)
# ✓ Embedded: 'I love you' by Dadju (9 sections)
# ✓ Embedded: 'Me & U' by Tems (9 sections)
# ✓ Embedded: 'Romeo Must Die (RMD)' by Ruger (5 sections)
# ✓ Embedded: 'One Dance' by Drake (11 sections)
# ✓ Embedded: 'Fi Kan We Kan' by Bnxn (5 sections)
# ✓ Embedded: 'Terminator' by Asake (7 sections)
# ✓ Embedded: 'Petit génie' by Jungeli (8 sections)
# ✓ Embedded: 'ZAAZAA' by Frenna (6 sections)
# ✓ Embedded: 'Dumebi' by Rema (10 sections)
# ✓ Embedded: 'Everything' by Victony (8 sections)
# ✓ Embedded: 'Lonely At The Top' by Asake (7 sections)
# ✓ Embedded: 'Laho II' by Shallipopi (8 sections)
# ✓ Embedded: 'Sempe' by L.A.X (6 sections)
# ✓ Embedded: 'Love Me JeJe' by Tems (9 sections)
# ✓ Embedded: 'Finesse' by Pheelz (6 sections)
# ✓ Embedded: 'Aquafina' by Young Jonn (8 sections)
# ✓ Embedded: 'Holy Ghost' by Omah Lay (7 sections)
# ✓ Embedded: 'Sability' by Ayra Starr (8 sections)
# ✓ Embedded: 'Damages' by Tems (8 sections)
# ✓ Embedded: 'Free Fallin’' by Tom Petty (9 sections)
# ✓ Embedded: 'Have You Ever Seen the Rain?' by Creedence Clearwater Revival (4 sections)
# ✓ Embedded: 'My Sweet Lord (2014 Remaster)' by George Harrison (14 sections)
# ✓ Embedded: 'For What It’s Worth' by Buffalo Springfield (8 sections)
# ✓ Embedded: 'Wild World' by Cat Stevens (7 sections)
# ✓ Embedded: 'You’re So Vain' by Carly Simon (13 sections)
# ✓ Embedded: 'Knockin’ on Heaven’s Door' by Bob Dylan (6 sections)
# ✓ Embedded: 'The Times They Are A-Changin’' by Bob Dylan (5 sections)
# ✓ Embedded: 'Friend of the Devil' by The Grateful Dead (12 sections)
# ✓ Embedded: 'Blowin’ in the Wind' by Bob Dylan (6 sections)
# ✓ Embedded: 'It’s Too Late' by Carole King (8 sections)
# ✓ Embedded: 'Father and Son' by Cat Stevens (5 sections)
# ✓ Embedded: 'Peace Train' by Cat Stevens (12 sections)
# ✓ Embedded: 'The Wind' by Cat Stevens (4 sections)
# ✓ Embedded: 'Don’t Think Twice, It’s All Right' by Bob Dylan (4 sections)
# ✓ Embedded: 'El Cóndor Pasa (If I Could)' by Simon & Garfunkel (5 sections)
# ✓ Embedded: 'Touch of Grey' by The Grateful Dead (11 sections)
# ✓ Embedded: 'Bye Bye Love' by ​The Everly Brothers (5 sections)
# ✓ Embedded: 'The Old Man’s Back Again (Dedicated to the Neo-Stalinist Regime)' by Scott Walker (8 sections)
# ✓ Embedded: 'Wake Up Little Susie' by ​The Everly Brothers (12 sections)
# ✓ Embedded: 'Operator (That’s Not the Way It Feels)' by Jim Croce (7 sections)
# ✓ Embedded: 'Up on cripple creek - 2000 - remaster' by The Band (1 sections)
# ✓ Embedded: 'Wasn’t Born to Follow' by The Byrds (6 sections)
# ✓ Embedded: 'California Stars' by Billy Bragg and Wilco (5 sections)
# ✓ Embedded: 'I Hope That I Don’t Fall in Love with You' by Tom Waits (5 sections)
# ✓ Embedded: 'Ramblin’ Man' by The Allman Brothers Band (7 sections)
# ✓ Embedded: 'The night they drove old dixie down - 2000 - remaster' by The Band (1 sections)
# ✓ Embedded: 'The Universal Soldier' by Buffy Sainte-Marie (6 sections)
# ✓ Embedded: 'You Ain’t Goin’ Nowhere' by The Byrds (1 sections)
# ✓ Embedded: 'Blues Run the Game (2001 - Remaster)' by Jackson C. Frank (7 sections)
# ✓ Embedded: 'You Can’t Always Get What You Want' by The Rolling Stones (10 sections)
# ✓ Embedded: 'Girl in the War' by Josh Ritter (1 sections)
# ✓ Embedded: 'Wolves' by Josh Ritter (6 sections)

# %% [markdown]
# # Examine Embeddings

# %%
# 1. Check collection stats
print(f"Songs: {songs_collection.count()}")
print(f"Sections: {sections_collection.count()}")
# Out:
# Songs: 4095
# Sections: 25734

# %%
# 2. Peek at a document
result = songs_collection.peek(limit=1)
print(result.keys())
print(result['documents'][0][:200])  # First 200 chars
print(result['metadatas'][0])
# Out:
# dict_keys(['ids', 'embeddings', 'documents', 'uris', 'included', 'data', 'metadatas'])
# 88 Contributors Translations Deutsch Free Fallin’ Lyrics “Free Fallin',” one of Tom Petty’s biggest hits, is an escapist’s ode to Los Angeles, California. The song, which peaked at #7 on the Billboard
# {'release_date': 'April 24, 1989', 'artist': 'Tom Petty', 'url': 'https://genius.com/Tom-petty-free-fallin-lyrics', 'title': 'Free Fallin’'}

# %%
QUERY_TEXTS = ["hearttbreak and longing"]

# 3. Test semantic search
results = songs_collection.query(
    query_texts=QUERY_TEXTS,
    n_results=3
)
for i, (doc, meta, dist) in enumerate(zip(results['documents'][0], 
                                           results['metadatas'][0],
                                           results['distances'][0])):
    print(f"{i+1}. {meta['title']} - {meta['artist']} (distance: {dist:.3f})")
    print(f"   {doc[:100]}...\n")

# %%
results = sections_collection.query(
    query_texts=QUERY_TEXTS,
    n_results=5
)

for i, (doc, meta, dist) in enumerate(zip(results['documents'][0], 
                                           results['metadatas'][0],
                                           results['distances'][0])):
    print(f"{i+1}. {meta['title']} - {meta['artist']} (distance: {dist:.3f})")
    print(f"   {doc[:100]}...\n")

# %%
# 4. Check embedding dimensions
result = songs_collection.get(limit=1, include=['embeddings'])
print(f"Embedding dims: {len(result['embeddings'][0])}")  # Should be 384 for MiniLM

# %% [markdown]
# # Find types of tracks in scraped content to filter for songs

# %%
import json
from collections import Counter

with open('songs_data.json', 'r') as f:
    songs = json.load(f)

# Analyze titles for non-song keywords
titles = [s['metadata']['title'].lower() for s in songs]
suspicious_words = ['transcript', 'audiobook', 'interview', 'spoken', 'commentary', 'dialogue']

flagged = []
for song in songs:
    title = song['metadata']['title'].lower()
    if any(word in title for word in suspicious_words):
        flagged.append(song['metadata']['title'])

print(f"Flagged {len(flagged)} potential non-songs:")
for t in flagged[:20]:
    print(f"  - {t}")
# Out:
# Flagged 1 potential non-songs:
#   - cubicle dialogue

# %% [markdown]
# # Scratch

# %%
import json

with open('songs_data_25_e.json') as f:
    songs = json.load(f)

# Check first song
print(songs[0]['metadata'].keys())
print(json.dumps(songs[0]['metadata'], indent=2))

# Count enriched songs
enriched = sum(1 for s in songs if s.get('metadata', {}).get('genres'))
print(f"\n{enriched}/{len(songs)} songs have genres")
# Out:
# dict_keys(['title', 'artist', 'url', 'release_date', 'genius_id', 'genres', 'artist_popularity'])
# {
#   "title": "Free Fallin\u2019",
#   "artist": "Tom Petty",
#   "url": "https://genius.com/Tom-petty-free-fallin-lyrics",
#   "release_date": "April 24, 1989",
#   "genius_id": 113622,
#   "genres": [
#     "classic rock"
#   ],
#   "artist_popularity": 68
# }
#
# 21/25 songs have genres
